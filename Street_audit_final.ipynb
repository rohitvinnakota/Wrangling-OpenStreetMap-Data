# %% [markdown]
# # Wrangling OpenStreetMap Data by Rohit Vinnakota

# %% [markdown]
# ## 1. Parsing the file

# %%
import xml.etree.ElementTree as ET
from collections import defaultdict
from bs4 import BeautifulSoup
import pprint
import csv
import codecs
import cerberus
import schema
import re

FILEPATH = "edmonton_canada.osm"


# Helper functions for parsing and wrangling


#Returns true if the element is a street name
def is_street_name(elem):
    if (elem.attrib['k'] == "addr:street"):
        return True

# Counts and returns the different number of tags and their types
def count_tags(filename):
    tree = ET.parse(filename)
    root = tree.getroot()
    dict1={}
    dict1[root.tag] = 1
    dup_list = []
    for a in root.findall('.//'):
        if a.tag not in dup_list:
            dup_list.append(a.tag)
            dict1[a.tag] = 1
    else:
        dict1[a.tag]+= 1

    return dict1


#Returns the number of users
def list_of_users(filename):
    users = set()
    user_cont = {}
    for _, elem in ET.iterparse(filename):
        users.add(elem.attrib.get('user'))
        if elem.attrib.get('user') in user_cont:
            user_cont[elem.attrib.get('user')]+=1
        else:
            user_cont[elem.attrib.get('user')] = 1
    del user_cont[None] #Some elements have an empty user value, I delete all the "None" users in this case
    return users,user_cont

#Returns true if the element is a zipcode
def is_zipcode(elem):
    if (elem.attrib['k'] == "addr:postcode"):
        return True
 
#Audits non existent names in our final street list 
def audit_street(street_types,name): 
    lastTwoWords = name.split()[-2:] # http://stackoverflow.com/questions/13482586/how-can-i-tell-python-to-take-the-last-2-words-from-an-email-that-is-in-a-list-l
    if len(lastTwoWords) == 2:
        for i in range(2):
            if (lastTwoWords[i] not in final_street_list):
                street_types[lastTwoWords[i]].add(name)

#Audits incorrect zipcodes
def audit_zipcode(zipcode,wrong_codes):
    if zipcode[:1] != 'T' or len(zipcode) != 6:
        wrong_codes.append(zipcode)


print(count_tags(FILEPATH))
# Out:
# {'node': 1, 'nd': 1, 'bounds': 1, 'member': 1, 'tag': 2, 'osm': 1, 'way': 1, 'relation': 1}

# %% [markdown]
# ## 2. Using site scraping to obtain a list of valid street names

# %% [markdown]
# Rather than typing up all the street names, I will use beautiful soup on the attached html file(URL: http://gimme-shelter.com/term-2/steet-types-designations-abbreviations-50006/) to obtain a list of all the street names

# %%
soup1 = BeautifulSoup(open("Streets.html"),"lxml")

# %%
street_list = []

tables = (soup1.findAll('tbody'))         #returns list of all the tables. 
                                      #there is only one table in this case
    
row_list = tables[0].findAll('tr')
for row in row_list:
    name_list = row.findAll('td')
    for name in name_list:
        street = name.string
        street_list.append(street)
            
print(street_list)
# Out:
# [u'Street Type', u'Abbreviation (Mail)', u'Abbreviation (Edmonton)', None, None, None, u'Abbey', u'ABBEY', u'\u2013', u'Acres', u'ACRES', u'AC', u'Alley or All\xe9e', u'ALLEY or ALL\xc9E', u'AL', u'Autoroute', u'AUT', u'\u2013', u'Avenue', u'AVE or AV', u'AV', u'Bay', u'BAY', u'BA', u'Beach', u'BEACH', u'BE', u'Bend', u'BEND', u'BN', u'Boulevard', u'BLVD or BOUL', u'BV', u'By-pass', u'BYPASS', u'\u2013', u'Byway', u'BYWAY', u'\u2013', u'Campus',
', u'Path', u'Pathway', u'Pines', u'Place', u'Plateau', u'Plaza', u'Point or Pointe', u'Pond', u'Port', u'Private', u'Promenade', u'Quai', u'Quary', u'Quay', u'Ramp', u'Ranch', u'Rang', u'Range', u'Ridge', u'Rise', u'Road', u'Rond-point', u'Route', u'Row', u'Rue', u'Ruelle', u'Run', u'Sentier', u'Shores', u'Springs', u'Square', u'Street', u'Subdivision', u'Summit', u'Terrace or Terrasse', u'Thicket', u'Towers', u'Townline', u'Trail', u'Turnabout', u'Two', u'Vale', u'Via', u'View', u'Village', u'Villa or Villas', u'Vista', u'Voie', u'Walk or Walkway', u'Way', u'Wharf', u'Wood or Woods', u'Wynd']

# %%
for item in final_street_list:
    if item.find(" or") != -1:
        N = item.split()
        final_street_list.append(N[0])
        final_street_list.append(N[2])
        final_street_list.remove(item)
        
print(final_street_list)
# Out:
# [u'Abbey', u'Acres', u'Autoroute', u'Avenue', u'Bay', u'Beach', u'Bend', u'Boulevard', u'By-pass', u'Byway', u'Campus', u'Cape', u'Carr\xe9', u'Carrefour', u'Castle', u'Centre', u'Cercle', u'Chase', u'Chemin', u'Circle', u'Circuit', u'Close', u'Common', u'Concession', u'Corners', u'C\xf4te', u'Cour', u'Cours', u'Court', u'Cove', u'Crest', u'Cross', u'Crossing', u'Cul-de-sac', u'Dale', u'Dell', u'Diversion', u'Downs', u'Drive', u'\xc9changeur', u'End', u'Esplanade', u'Estates', u'Expressway', u'Extension', u'Farm', u'Field', u'Forest', u'Freeway', u'Front', u'Gardens', u'Gate', u'Gateway', u'Glade', u'Glen', u'Green', u'Grounds', u'Grove', u'Hall', u'Harbour', u'Haven', u'Heath', u'Heights', u'Highlands', u'Highway', u'Hollow', u'\xcele', u'Impasse', u'Inlet', u'Island', u'Keep', u'Key', u'Knoll', u'Lake', u'Landing', u'Lane', u'Limits', u'Line', u'Link', u'Lookout', u'Loop', u'Mall', u'Manor', u'Maze', u'Mews', u'Mont\xe9e', u'Moor', u'Mount', u'Mountain', u'Not Applicable', u'Oaks', u'Orchard', u'Parade', u'Parkway', u'Passage', u'Path', u'Pathway', u'Pines', u'Place', u'Plateau', u'Plaza', u'Pond', u'Port', u'Private', u'Promenade', u'Quai', u'Quary', u'Quay', u'Ramp', u'Ranch', u'Rang', u'Range', u'Ridge', u'Rise', u'Road', u'Rond-point', u'Route', u'Row', u'Rue', u'Ruelle', u'Run', u'Sentier', u'Shores', u'Springs', u'Square', u'Street', u'Subdivision', u'Summit', u'Thicket', u'Towers', u'Townline', u'Trail', u'Turnabout', u'Two', u'Vale', u'Via', u'View', u'Village', u'Vista', u'Voie', u'Way', u'Wharf', u'Wynd', u'Alley', u'All\xe9e', u'Crescent', u'Croissant', u'Hill', u'Hills', u'Meadow', u'Meadows', u'Park', u'Parc', u'Point', u'Pointe', u'Terrace', u'Terrasse', u'Villa', u'Villas', u'Walk', u'Walkway', u'Wood', u'Woods']

# %% [markdown]
# ## 3. Basic querying using python libraries

# %% [markdown]
# After some cleaning , we can construct an appropriate mapping dictionary. But first, let us get some insights on the uncleaned data.

# %%
x,y = list_of_users(FILEPATH)
print(len(x))
print("\n")
# Out:
# 619

# %% [markdown]
# The number of users who contributed to the website for the map area chosen

# %%
# http://stackoverflow.com/questions/26871866/print-highest-value-in-dict-with-key

maximum = max(y, key = y.get)  # Just use 'min' instead of 'max' for minimum.
print(maximum, y[maximum])
# Out:
# ('edmontongeo', 2407878)

# %% [markdown]
# This is the user with the most contributions. It seems to be a bot or a company which would be appropriate.

# %% [markdown]
# ## 4. Updating incorrect street names and auditing zipcodes

# %%
street_types = defaultdict(set) #Audit whole street type instead of last word


for event, elem in ET.iterparse(FILEPATH, events=("start",)):# Change to iterate over last 2 elements instead of last one
    if elem.tag == "way" or elem.tag == "node":
        for tag in elem.iter("tag"):
            if (is_street_name(tag)):
                audit_street(street_types,tag.attrib['v'])
pprint.pprint(dict(street_types))
# Out:
# {'1': set(['1 Avenue', '1 Street']),
#  '10': set(['10 Street', '50322 Range Road 10', 'Range Road  10']),
#  '100': set(['100 Avenue', '100 Street', 'Sturgeon 100 Crescent']),
#  '100A': set(['100A Avenue', '100A Street']),
#  '101': set(['101 Avenue', '101 Street', '101 street']),
#  '101A': set(['101A Street']),
#  '102': set(['102 Avenue', '102 Street']),
#  '103': set(['103 Avenue', '103 Street']),
#  '103A': set(['103A Avenue', '103A Street']),
#  '104': set(['104 Avenue', '104 Street']),
#  '105': set(['105 Avenue', '105 Street']),
#  '106': set(['106 Avenue', '106 Street']),
#  '106A': set(['106A Avenue']),
#  '107': set(['107 Avenue', '107 St', '107 Street', '107 street']),
#  '107A': set(['107A Avenue']),
#  '108': set(['108 Avenue', '108 Street']),
#  '108A': set(['108A Avenue', '108A Street']),
#  '109': set(['109 Avenue', '109 Street', '109 street']),
#  '109A': set(['109A Street']),
#  '11': set(['11 Avenue', 'Range Road  11']),
#  '110': set(['110 Avenue', '110 Street']),
#  '110A': set(['110A Street']),
#  '111': set(['111 Avenue', '111 Street']),
#  '112': set(['112 Street']),
#  '112th': set(['8219 - 112th Street']),
#  '113': set(['113 Street']),
#  '114': set(['114 Street']),
#  '115': set(['115 Avenue', '115 Street']),
#  '119': set(['119 Street']),
#  '11A': set(['Range Road  11A']),
#  '12': set(['12 Avenue',
#             '53127 Range Road 12',
#             '53302 Range Road 12',
#             '54120 Range Road 12',
#             '54130 Range Road 12',
#             'Range Road  12']),
#  '125': set(['125 Street']),
#  '127': set(['127 street']),
#  '12A': set(['Range Road  12A']),
#  '12B': set(['Range Road  12B']),
#  '13': set(['13 Avenue',
#             '52419 Range Road 13',
#             '52420 Range Road 13',
#             '52516 Range Road 13',
#             '53104 Range Road 13',
#             '53130 Range Road 13',
#             '53226 Range Road 13',
#             '53424 Range Road 13',
#             '53516 Range Road 13',
#             '54113 Range Road 13',
#             'Range Road  13']),
#  '132': set(['132 St.']),
#  '13A': set(['Range Road  13A']),
#  '14': set(['14 Avenue',
#             '14 Highway',
#             '21324 Highway 14',
#             '53103 Range Road 14',
#             '53106 Range Road 14',
#             '53117 Range Road 14',
#             '53122 Range Road 14',
#             '53129 Range Road 14',
#             '53218 Range Road 14',
#             '53227 Range Road 14',
#             '53304 Range Road 14',
#             '53319 Range Road 14',
#             '53322 Range Road 14',
#             '53417 Range Road 14',
#             '53424 Range Road 14',
#             '53504 Range Road 14',
#             'Range Road  14']),
#  '142': set(['10706 142 Street']),
#  '144': set(['144 Avenue']),
#  '15': set(['15 Avenue',
#             '15 Highway',
#             '52330 Range Road 15',
#             '52417 Range Road 15',
#             '52421 Range Road 15',
#             '53024 Range Road 15',
#             '53105 Range Road 15',
#             '53107 Range Road 15',
#             '53120 Range Road 15',
#             '53203 Range Road 15',
#             '53212 Range Road 15',
#             '53220 Range Road 15',
#             '53227 Range Road 15',
#             '53228 Range Road 15',
#             '53303 Range Road 15',
#             '53304 Range Road 15',
#             '53310 Range Road 15',
#             '53319 Range Road 15',
#             '53327 Range Road 15',
#             'Range Road  15']),
#  '15A': set(['15A Avenue', 'Range Road  15A']),
#  '16': set(['16 Highway']),
#  '160': set(['160 Avenue']),
#  '167': set(['13 St & 167 Ave']),
#  '16A': set(['16A Highway']),
#  '17': set(['17 Avenue', '17 Street']),
#  '170': set(['170 street']),
#  '18': set(['18 Avenue', '18 Highway', '18 Street']),
#  '19': set(['19 Avenue']),
#  '2': set(['2 Avenue', '2 Street']),
#  '20': set(['20 Highway',
#             '20 Street',
#             '52019 Range Road 20',
#             '52327 Range Road 20',
#             '52414 Range Road 20',
#             '52432 Range Road 20',
#             '52510 Range Road 20',
#             '52524 Range Road 20',
#             '53009 Range Road 20',
#             '53027 Range Road 20',
#             '53030 Range Road 20',
#             '53112 Range Road 20',
#             '53203 Range Road 20',
#             '53213 Range Road 20',
#             '53303 Range Road 20',
#             '53306 Range Road 20',
#             '53314 Range Road 20',
#             '53315 Range Road 20',
#             '53325 Range Road 20',
#             '53333 Range Road 20',
#             'Range Road  20']),
#  '203': set(['Range Road  203']),
#  '204': set(['51042 Range Road 204',
#              '51263 Range Road 204',
#              '51268 Range Road 204',
#              'Range Road  204']),
#  '205': set(['Range Road  205']),
#  '20A': set(['Range Road  20A']),
#  '21': set(['21 Avenue',
#             '21 Highway',
#             '21 Street',
#             '50525 Range Road 21',
#             '50529 Range Road 21',
#             '51314 Range Road 21',
#             '52260 Highway 21',
#             '52328 Highway 21',
#             '52351 Highway 21',
#             '52403 Range Road 21',
#             '52411 Range Road 21',
#             '52437 Range Road 21',
#             '52477 Highway 21',
#             '52508 Range Road 21',
#             '52519 Range Road 21',
#             '52520 Range Road 21',
#             '52559 Highway 21',
#             '53111 Range Road 21',
#             '53123 Range Road 21',
#             '53220 Range Road 21',
#             'Range Road  21']),
#  '210': set(['Range Road  210', 'Range Road 210']),
#  '210A': set(['Range Road  210A']),
#  '210C': set(['Range Road 210C']),
#  '211': set(['Range Road  211', 'Range Road 211']),
#  '211A': set(['Range Road 211A']),
#  '212': set(['51058 Range Road 212',
#              '51110 Range Road 212',
#              '52306 Range Road 212',
#              '52306 Range Road 212 Place',
#              '53160 Range Road 212',
#              'Range Road  212',
#              'Range Road 212']),
#  '212A': set(['51551 Range Road 212A', 'Range Road  212A']),
#  '213': set(['52039 Range Road 213',
#              '52250 Range Road 213',
#              '52307 Range Road 213',
#              '52318 Range Road 213',
#              '52465 Range Road 213',
#              '52510 Range Road 213',
#              '52510 Range Road 213 Road',
#              '53110 Range Road 213',
#              '53462 Range Road 213',
#              'Range Road  213',
#              'Range Road 213']),
#  '213A': set(['Range Road  213A']),
#  '213B': set(['Range Road  213B']),
#  '214': set(['51049 Range Road 214',
#              '51110 Range Road 214',
#              '51218 Range Road 214',
#              '52009 Range Road 214',
#              '52055 Range Road 214',
#              '52110 Range Road 214',
#              '52308 Range Road 214',
#              '52411 Range Road 214',
#              '52467 Range Road 214',
#              '52505 Range Road 214',
#              '52512 Range Road 214',
#              '52561 Range Road 214',
#              '53050 Range Road 214',
#              'Range Road  214',
#              'Range Road 214']),
#  '214A': set(['Range Road  214A']),
#  '215': set(['51049 Range Road 215',
#              '51069 Range Road 215',
#              '52013 Range Road 215',
#              '52061 Range Road 215',
#              '52252 Range Road 215',
#              '52349 Range Road 215',
#              '53158 Range Road 215',
#              '53250 Range Road 215',
#              '53347 Range Road 215',
#              '54569 Range Road 215',
#              'Range Road  215',
#              'Range Road 215']),
#  '215A': set(['Range Road  215A', 'Range Road 215A']),
#  '215B': set(['Range Road  215B']),
#  '22': set(['22 Avenue',
#             '51513 Range Road 22',
#             '52427 Range Road 22',
#             '52505 Range Road 22',
#             '53111 Range Road 22',
#             '53121 Range Road 22',
#             '53217 Range Road 22',
#             'Range Road  22']),
#  '220': set(['51109 Range Road 220',
#              '51519 Range Road 220',
#              '52059 Range Road 220',
#              '52105 Range Road 220',
#              '52117 Range Road 220',
#              '52312 Range Road 220',
#              '52442 Range Road 220',
#              '53049 Range Road 220',
#              '53050 Range Road 220',
#              '53111 Range Road 220',
#              '53455 Range Road 220',
#              'Range Road  220',
#              'Range Road 220']),
#  '220A': set(['Range Road  220A']),
#  '221': set(['51022 Range Road 221',
#              '51047 Range Road 221',
#              '51107 Range Road 221',
#              '51401 Range Road 221',
#              '52150 Range Road 221',
#              '52356 Range Road 221',
#              '52470 Range Road 221',
#              '52470 Range Road 221 Road',
#              '53310 Range Road 221',
#              '53431 Range Road 221',
#              'Range Road  221',
#              'Range Road 221']),
#  '221A': set(['53037 Range Road 221A', 'Range Road  221A']),
#  '222': set(['51025 Range Road 222',
#              '51112 Range Road 222',
#              '52112 Range Road 222',
#              '52249 Range Road 222',
#              '52349 Range Road 222',
#              '52449 Range Road 222',
#              '52450 Range Road 222',
#              '52521 Range Road 222',
#              '52550 Range Road 222',
#              '53016 Range Road 222',
#              '53046 Range Road 222',
#              '53151 Range Road 222',
#              'Range Road  222',
#              'Range Road 222']),
#  '222A': set(['Range Road  222A']),
#  '223': set(['52242 Range Road 223',
#              '52260 Range Road 223',
#              '52260 Range Road 223 Estate',
#              '52311 Range Road 223',
#              '52312 Range Road 223',
#              '52368 Range Road 223',
#              '52409 Range Road 223',
#              '52435 Range Road 223',
#              '52458 Range Road 223',
#              '52471 Range Road 223',
#              '52514 Range Road 223',
#              '52548 Range Road 223',
#              '52555 Range Road 223',
#              '53017 Range Road 223',
#              '53025 Range Road 223',
#              '53221 Range Road 223',
#              '53271 Range Road 223',
#              'Range Road  223',
#              'Range Road 223']),
#  '223A': set(['Range Road  223A']),
#  '223B': set(['Range Road  223B']),
#  '223C': set(['Range Road  223C']),
#  '224': set(['51308 Range Road 224',
#              '51331 Range Road 224',
#              '51350 Range Road 224',
#              '51509 Range Road 224',
#              '51561 Range Road 224',
#              '52109 Range Road 224',
#              '52333 Range Road 224',
#              '52422 Range Road 224',
#              '52472 Range Road 224',
#              '52552 Range Road 224',
#              '53059 Range Road 224 Drive',
#              '54150 Range Road 224',
#              'Range Road  224',
#              'Range Road 224']),
#  '224A': set(['Range Road  224A']),
#  '225': set(['51052 Range Road 225',
#              '51149 Range Road 225',
#              '51309 Range Road 225',
#              '51369 Range Road 225',
#              '51559 Range Road 225',
#              '52063 Range Road 225',
#              '52105 Range Road 225',
#              '52145 Range Road 225',
#              '52152 Range Road 225',
#              '52152 Range Road 225 Road',
#              '52245 Range Road 225',
#              '52312 Range Road 225',
#              '52331 Range Road 225',
#              '52358 Range Road 225',
#              '52467 Range Road 225',
#              '52519 Range Road 225',
#              '52545 Range Road 225',
#              '52550 Range Road 225',
#              '52555 Range Road 225',
#              '53038 Range Road 225',
#              '53279 Range Road 225',
#              'Range Road  225',
#              'Range Road 225']),
#  '225A': set(['51561 Range Road 225A', 'Range Road  225A']),
#  '225B': set(['Range Road  225B']),
#  '225D': set(['Range Road  225D']),
#  '225F': set(['Range Road  225F']),
#  '22A': set(['Range Road  22A']),
#  '22B': set(['Range Road  22B']),
#  '23': set(['23 Avenue', 'Range Road  23']),
#  '230': set(['Range Road  230', 'Range Road 230']),
#  '230A': set(['Range Road  230A']),
#  '231': set(['51149 Range Road 231',
#              '51247 Range Road 231',
#              '51248 Range Road 231',
#              '51313 Range Road 231',
#              '51351 Range Road 231',
#              '51430 Range Road 231',
#              '52147 Range Road 231',
#              '52148 Range Road 231',
#              '52224 Range Road 231',
#              '52258 Range Road 231',
#              '52319 Range Road 231',
#              'Range Road  231',
#              'Range Road 231']),
#  '231A': set(['Range Road  231A']),
#  '232': set(['52063 Range Road 232',
#              '52210 Range Road 232',
#              '52225 Range Road 232',
#              '52245 Range Road 232',
#              '52246 Range Road 232',
#              '52310 Range Road 232',
#              '52313 Range Road 232',
#              'Range Road  232',
#              'Range Road 232']),
#  '232A': set(['Range Road  232A']),
#  '233': set(['52010 Range Road 233',
#              '52216 Range Road 233',
#              '52249 Range Road 233',
#              '52304 Range Road 233',
#              'Range Road  233',
#              'Range Road 233']),
#  '233A': set(['Range Road  233A']),
#  '234': set(['Range Road  234', 'Range Road 234']),
#  '234A': set(['Range Road  234A', 'Range Road 234A']),
#  '235': set(['Range Road  235', 'Range Road 235']),
#  '235A': set(['Range Road  235A']),
#  '235B': set(['Range Road  235B']),
#  '23A': set(['Range Road  23A']),
#  '23rd': set(['23rd Avenue']),
#  '24': set(['24 Street',
#             '52215 Range Road 24',
#             '52231 Range Road 24',
#             '52330 Range Road 24',
#             'Range Road  24']),
#  '240': set(['Range Road  240', 'Range Road 240']),
#  '240A': set(['Range Road  240A', 'Range Road 240A']),
#  '241': set(['Range Road  241', 'Range Road 241']),
#  '241A': set(['Range Road  241A']),
#  '242': set(['Range Road  242', 'Range Road 242']),
#  '242A': set(['Range Road  242A']),
#  '242B': set(['Range Road  242B', 'Range Road 242B']),
#  '243': set(['Range Road  243', 'Range Road 243']),
#  '243A': set(['Range Road  243A']),
#  '244': set(['Range Road  244', 'Range Road 244']),
#  '244A': set(['Range Road  244A']),
#  '244C': set(['Range Road  244C']),
#  '245': set(['54324 Range Road 245', 'Range Road  245', 'Range Road 245']),
#  '245A': set(['Range Road  245A']),
#  '245B': set(['Range Road  245B']),
#  '245C': set(['Range Road  245C']),
#  '25': set(['25 Avenue',
#             '52111 Range Road 25',
#             '52212 Range Road 25',
#             '52229 Range Road 25',
#             '52318 Range Road 25',
#             '52502 Range Road 25',
#             '52510 Range Road 25',
#             '53220 Range Road 25',
#             '53221 Range Road 25',
#             '53322 Range Road 25',
#             'Range Road  25']),
#  '250': set(['Range Road  250', 'Range Road 250']),
#  '250A': set(['Range Road  250A', 'Range Road 250A']),
#  '250B': set(['Range Road  250B']),
#  '250C': set(['Range Road  250C']),
#  '251': set(['Range Road  251', 'Range Road 251']),
#  '251B': set(['Range Road  251B']),
#  '251C': set(['Range Road  251C']),
#  '252': set(['Range Road  252', 'Range Road 252']),
#  '252A': set(['Range Road  252A']),
#  '252B': set(['Range Road  252B']),
#  '252C': set(['Range Road  252C']),
#  '253': set(['Range Road  253', 'Range Road 253']),
#  '253A': set(['Range Road  253A']),
#  '254': set(['Range Road  254', 'Range Road 254']),
#  '255': set(['Range Road  255', 'Range Road 255']),
#  '255A': set(['Range Road  255A']),
#  '25A': set(['Range Road  25A']),
#  '260': set(['Range Road  260', 'Range Road 260']),
#  '260A': set(['Range Road  260A']),
#  '261': set(['54020 Range Road 261', 'Range Road  261', 'Range Road 261']),
#  '262': set(['Range Road  262', 'Range Road 262']),
#  '262A': set(['Range Road  262A']),
#  '262a': set(['Range Road  262a']),
#  '263': set(['51024 Range Road 263',
#              '53217 Range Road 263',
#              'Range Road  263',
#              'Range Road 263']),
#  '263A': set(['56500 Range Road 263A', 'Range Road  263A']),
#  '263B': set(['Range Road  263B']),
#  '264': set(['51114 Range Road 264',
#              '51124 Range Road 264',
#              '51228 Range Road 264',
#              '51404 Range Road 264',
#              '51504 Range Road 264',
#              '51511 Range Road 264',
#              '51530 Range Road 264',
#              '53106 Range Road 264',
#              'Range Road  264',
#              'Range Road 264']),
#  '264A': set(['Range Road  264A']),
#  '265': set(['51119 Range Road 265',
#              '51122 Range Road 265',
#              '51216 Range Road 265',
#              '51221 Range Road 265',
#              '51513 Range Road 265',
#              '52426 Range Road 265',
#              '54200 Range Road 265',
#              'Range Road  265',
#              'Range Road 265']),
#  '265A': set(['Range Road  265A']),
#  '265C': set(['Range Road  265C']),
#  '270': set(['51113 Range Road 270',
#              '51121 Range Road 270',
#              '51205 Range Road 270',
#              '51214 Range Road 270',
#              '51222 Range Road 270',
#              '51420 Range Road 270',
#              '51503 Range Road 270',
#              '52004 Range Road 270',
#              '52020 Range Road 270',
#              '52215 Range Road 270',
#              'Range Road  270',
#              'Range Road 270']),
#  '270A': set(['Range Road  270A', 'Range Road 270A']),
#  '270B': set(['Range Road  270B']),
#  '271': set(['51121 Range Road 271',
#              '51330 Range Road 271',
#              '51409 Range Road 271',
#              '51410 Range Road 271',
#              '51425 Range Road 271',
#              '51426 Range Road 271',
#              '51524 Range Road 271',
#              '52524 Range Road 271',
#              '53219 Range Road 271',
#              'Range Road  271',
#              'Range Road 271']),
#  '271A': set(['Range Road  271A']),
#  '272': set(['51032 Range Road 272',
#              '51421 Range Road 272',
#              '52212 Range Road 272',
#              '53412 Range Road 272',
#              '53521 Range Road 272',
#              '53522 Range Road 272',
#              'Range Road  272',
#              'Range Road 272']),
#  '272A': set(['Range Road  272A']),
#  '273': set(['51526 Range Road 273',
#              '52225 Range Road 273',
#              '53305 Range Road 273',
#              '53306 Range Road 273',
#              'Range Road  273',
#              'Range Road 273']),
#  '273A': set(['Range Road  273A']),
#  '274': set(['52112 Range Road 274',
#              '52120 Range Road 274',
#              '52132 Range Road 274',
#              '52212 Range Road 274',
#              '52222 Range Road 274',
#              '52312 Range Road 274',
#              '53420 Range Road 274',
#              '53424 Range Road 274',
#              '53503 Range Road 274',
#              '53504 Range Road 274',
#              '53522 Range Road 274',
#              '54006 Range Road 274',
#              '54030 Range Road 274',
#              'Range Road  274']),
#  '274A': set(['Range Road  274A']),
#  '275': set(['50410 Range Road 275',
#              '50412 Range Road 275',
#              '52001 Range Road 275',
#              '52125 Range Road 275',
#              '52208 Range Road 275',
#              '52211 Range Road 275',
#              '52218 Range Road 275',
#              '52224 Range Road 275',
#              '53203 Range Road 275',
#              '53206 Range Road 275',
#              '53310 Range Road 275',
#              '53532 Range Road 275',
#              '54014 Range Road 275',
#              '54022 Range Road 275',
#              '54029 Range Road 275',
#              '54030 Range Road 275',
#              '54106 Range Road 275',
#              '54129 Range Road 275',
#              'Range Road  275']),
#  '28': set(['28 Highway']),
#  '280': set(['53305 Range Road 280',
#              '53313 Range Road 280',
#              '53319 Range Road 280',
#              '53420 Range Road 280',
#              '53504 Range Road 280',
#              '53522 Range Road 280',
#              '54023 Range Road 280',
#              '54108 Range Road 280',
#              'Range Road  280']),
#  '281': set(['Range Road  281']),
#  '281A': set(['Range Road  281A']),
#  '282A': set(['Range Road  282A']),
#  '28a': set(['28a Highway']),
#  '29': set(['29 Avenue']),
#  '2A': set(['2A Highway', '2A Street']),
#  '2nd': set(['2nd Avenue']),
#  '3': set(['3 Avenue', '3 Street']),
#  '30': set(['30 Avenue',
#             '52228 Range Road 30',
#             '52414 Range Road 30',
#             '53304 Range Road 30',
#             '53320 Range Road 30',
#             '53407 Range Road 30',
#             '53413 Range Road 30',
#             'Range Road  30']),
#  '30A': set(['Range Road  30A']),
#  '31': set(['53102 Range Road 31',
#             '53303 Range Road 31',
#             '53319 Range Road 31',
#             'Range Road  31']),
#  '31A': set(['Range Road  31A']),
#  '31B': set(['Range Road  31B']),
#  '32': set(['32 Avenue',
#             '53029 Range Road 32',
#             '53301 Range Road 32',
#             '53304 Range Road 32',
#             'Range Road  32']),
#  '32A': set(['51515 Range Road 32A', 'Range Road  32A']),
#  '32B': set(['Range Road  32B']),
#  '33': set(['33 Avenue', '33 Highway', 'Range Road  33', 'Range Road 33']),
#  '33A': set(['Range Road  33A']),
#  '34': set(['34 Avenue',
#             '53222 Range Road 34',
#             '53223 Range Road 34',
#             'Range Road  34']),
#  '34A': set(['34A Avenue', 'Range Road  34A']),
#  '34B': set(['Range Road  34B']),
#  '35': set(['35 Avenue', '53306 Range Road 35', 'Range Road  35']),
#  '35A': set(['Range Road  35A']),
#  '35B': set(['Range Road  35B']),
#  '36': set(['36 Avenue', '36 Street']),
#  '37': set(['37 Avenue', '37 Street']),
#  '37A': set(['37A Avenue']),
#  '37th': set(['37th Street']),
#  '38': set(['38 Avenue', '38 Highway', '38 Street']),
#  '39': set(['39 Avenue', '39 Street']),
#  '39A': set(['39A Avenue']),
#  '4': set(['4 Avenue', '4 Street']),
#  '40': set(['40 Avenue',
#             '40 Street',
#             '53102 Range Road 40',
#             '53103 Range Road 40',
#             'Range Road  40']),
#  '40A': set(['40A Avenue', '40A Street', 'Range Road  40A']),
#  '40th': set(['40th Avenue']),
#  '41': set(['41 Avenue',
#             '41 Street',
#             '53412 Range Road 41',
#             '53426 Range Road 41',
#             'Range Road  41']),
#  '41A': set(['41A Avenue', '41A Street', 'Range Road  41A']),
#  '41B': set(['41B Avenue', '41B Street']),
#  '41st': set(['41st Avenue']),
#  '42': set(['42 Avenue', '42 Street', 'Range Road  42']),
#  '42A': set(['42A Avenue']),
#  '42B': set(['42B Avenue']),
#  '42nd': set(['42nd Avenue', '42nd Street']),
#  '43': set(['43 Avenue', '43 Highway', '43 Street']),
#  '43A': set(['43A Avenue', '43A Street']),
#  '43B': set(['43B Avenue']),
#  '43rd': set(['43rd Avenue', '43rd Street']),
#  '44': set(['44 Avenue', '44 Highway', '44 Street', '53304 Highway 44']),
#  '44A': set(['44A Avenue', '44A Street']),
#  '44th': set(['44th Avenue', '44th Street']),
#  '45': set(['45 Avenue', '45 Street']),
#  '45A': set(['45A Street']),
#  '45th': set(['45th Avenue', '45th Street']),
#  '46': set(['46 Avenue', '46 Street']),
#  '461': set(['Township Road  461']),
#  '461A': set(['Township Road  461A']),
#  '462': set(['Township Road  462']),
#  '462A': set(['Township Road  462A']),
#  '463': set(['Township Road  463']),
#  '463B': set(['Township Road  463B']),
#  '464': set(['Township Road  464']),
#  '464A': set(['Township Road  464A']),
#  '465': set(['Township Road  465']),
#  '465A': set(['Township Road  465A']),
#  '46A': set(['46A Avenue', '46A St', '46A Street']),
#  '46B': set(['46B Street']),
#              '1219 Secondary Highway 633',
#              '27421 Secondary Highway 633']),
#  '64': set(['64 Avenue', '64 Street']),
#  '65': set(['65 Avenue', '65 Street']),
#  '66': set(['Ave. NW at 66 St.']),
#  '7': set(['7 Avenue', '7 Street']),
#  '71': set(['71 Avenue']),
#  '72': set(['72 Avenue']),
#  '75': set(['75 Avenue']),
#  '77': set(['77 Avenue']),
#  '770': set(['52204 Secondary Highway 770',
#              '52511 Secondary Highway 770',
#              '53025 Secondary Highway 770',
#              '770 Highway']),
#  '779': set(['53306 Secondary Highway 779',
#              '53512 Secondary Highway 779',
#              '54020 Secondary Highway 779',
#              '54023 Secondary Highway 779',
#              '779 Highway']),
#  '79': set(['79 Avenue', '79 Street']),
#  '794': set(['794 Route']),
#  '79th': set(['79th Avenue']),
#  '8': set(['8 Street']),
#  '80': set(['80 Avenue', '80 Street']),
#  '81': set(['81 Ave', '81 Avenue', '81 Street']),
#  '814': set(['Highway 814']),
#  '81A': set(['81A Street']),
#  '82': set(['82 Avenue', '82 Street']),
#  '824': set(['824 Highway']),
#  '82A': set(['82A Street']),
#  '83': set(['83 Avenue', '83 Street', 'Ave. at 83 St.']),
#  '830': set(['830 Highway']),
#  '83A': set(['83A Street']),
#  '84': set(['84 Avenue', '84 Street']),
#  '85': set(['85 Street']),
#  '85A': set(['85A Street']),
#  '86': set(['86 Avenue', '86 Street']),
#  '87': set(['117 street 87 avenue', '87 Avenue', '87 Street']),
#  '87A': set(['87A Street']),
#  '88': set(['88 Avenue', '88 Street']),
#  '89': set(['89 Street']),
#  '89A': set(['89A Street']),
#  '89B': set(['89B Street']),
#  '8a': set(['8a Street']),
#  '9': set(['9 Street']),
#  '90': set(['90 Avenue', '90 Street']),
#  '90A': set(['90A Street']),
#  '90th': set(['90th avenue']),
#  '91': set(['91 Avenue', '91 Street']),
#  '92': set(['92 Avenue', '92 Street']),
#  '92A': set(['92A Avenue']),
#  '93': set(['93 Avenue', '93 Street']),
#  '93A': set(['93A Avenue']),
#  '94': set(['94 Avenue', '94 Street']),
#  '94A': set(['94A Avenue']),
#  '95': set(['95 Avenue', '95 Street']),
#  '95A': set(['95A Avenue', '95A Street']),
#  '95B': set(['95B Avenue']),
#  '96': set(['96 Ave', '96 Avenue', '96 Street']),
#  '96A': set(['96A Avenue', '96A Street']),
#  '97': set(['97 Avenue', '97 Street']),
#  '97A': set(['97A Avenue']),
#  '98': set(['98 Avenue', '98 Street']),
#  '98A': set(['98A Street']),
#  '98a': set(['98a Street']),
#  '99': set(['99 Avenue', '99 Street']),
#  '99A': set(['99A Avenue']),
#  'AVE': set(['139 AVE EW', '42 AVE NW']),
#  'Abbott': set(['Abbott Crescent']),
#  'Abbottsford': set(['Abbottsford Place']),
#  'Abby': set(['Abby Drive']),
#  'Abel': set(['Abel Court', 'Abel Place']),
#  'Aberdeen': set(['Aberdeen Crescent', 'Aberdeen Place', 'Aberdeen Way']),
#  'Acacia': set(['Acacia Circle', 'Acacia Link']),
#  'Acadian': set(['Acadian Wynd']),
#  'Acorn': set(['Acorn Crescent']),
#  'Acreage': set(['Westerose Acreage Road']),
#  'Adamic': set(['Adamic Crescent']),
#  'Addison': set(['Addison Crescent']),
#  'Adrian': set(['Adrian Place']),
#  'Afton': set(['Afton Crescent']),
#  'Aicher': set(['Aicher Place']),
#  'Ainsley': set(['Ainsley Place']),
#  'Airport': set(['Airport Road']),
#  'Akins': set(['Akins Drive']),
#  'Akinsdale': set(['Akinsdale Gardens']),
#  'Alan': set(['Alan Place']),
#  'Alana': set(['Alana Court']),
#  'Albert': set(['St Albert Road',
#                 'St Albert Trail',
#                 'St. Albert Road',
#                 'St. Albert Trail']),
#  'Alberta': set(['Alberta Avenue']),
#  'Alcott': set(['Alcott Crescent']),
#  'Alder': set(['Alder Crescent', 'Alder Place']),
#  'Alderson': set(['Alderson Close']),
#  'Alderwood': set(['Alderwood Boulevard']),
#  'Alexander': set(['Alexander Drive']),
#  'Alexis': set(['Alexis Road']),
#  'Alicia': set(['Alicia Court']),
#  'Allard': set(['Allard Avenue', 'Allard Way']),
#  'Allen': set(['Allen Place']),
#  'Allison': set(['Allison Place']),
#  'Almond': set(['Almond Bay']),
#  'Alpaugh': set(['Alpaugh Crescent']),
#  'Alphonse': set(['Alphonse Court']),
#  'Alpine': set(['Alpine Boulevard', 'Alpine Place']),
#  'Alton': set(['Alton Drive']),
#  'Amber': set(['Amber Crescent']),
#  'Ameena': set(['Ameena Drive']),
#  'Amherst': set(['Amherst Crescent']),
#  'Anderson': set(['Anderson Court']),
#  'Andrew': set(['Andrew Crescent']),
#  'Andrews': set(['Andrews Crescent',
#                  'St. Andrews Avenue',
#                  'St. Andrews Crescent',
#                  'St. Andrews Drive',
#                  'St. Andrews Place',
#                  'St. Andrews Street']),
#  'Anise': set(['Anise Close']),
#  'Anita': set(['Anita Crescent']),
#  'Anne': set(['Lac St Anne Trail', 'St. Anne Street']),
#  'Annette': set(['Annette Crescent']),
#  'Apache': set(['Apache Crescent']),
#  'Apple': set(['Apple Place']),
#  'Applewood': set(['Applewood Street']),
#  'Arbor': set(['Arbor Crescent']),
#  'Arbour': set(['Arbour Close']),
#  'Arcand': set(['Arcand Drive', 'Arcand Lane']),
#  'Arlington': set(['Arlington Drive', 'Arlington Place', 'Arlington Street']),
#  'Armbruster': set(['Armbruster Terrace']),
#  'Armdale': set(['Armdale Close']),
#  'Armstrong': set(['Armstrong Crescent']),
#  'Arndt': set(['Arndt Court']),
#  'Ash': set(['Ash Close',
#              'Ash Crescent',
#              'Ash Place',
#              'Ash Point',
#              'Ash Street',
#              'Green Ash Drive',
#              'Mountain Ash Drive']),
#  'Ashgrove': set(['Ashgrove Bay']),
#  'Ashwood': set(['Ashwood Street']),
#  'Aspen': set(['Aspen Avenue',
#                'Aspen Crescent',
#                'Aspen Gate',
#                'Aspen Place',
#                'Aspen Way',
#                'Aspen Wynd']),
#  'Aspenglen': set(['Aspenglen Court',
#                    'Aspenglen Crescent',
#                    'Aspenglen Drive',
#                    'Aspenglen Place',
#                    'Aspenglen Way']),
#  'Aspenridge': set(['Aspenridge Crescent']),
#  'Aster': set(['Aster Close']),
#  'Athabasca': set(['Athabasca Acres', 'Athabasca Avenue', 'Athabasca Drive']),
#  'Athabascan': set(['Athabascan Avenue']),
#  'Athapaskan': set(['Athapaskan Drive']),
#  'Atkinson': set(['Atkinson Place']),
#  'Attwood': set(['Attwood Drive']),
#  'Aubrey': set(['Aubrey Place']),
#  'Austin': set(['Austin Crescent']),
#  'Ave': set(['13 St & 167 Ave',
#              '137 Ave NW',
#              '140 ST Mathews Ave',
#              '45 Ave NW',
#              '51 Ave',
#              '53 Ave NW',
#              '72 Ave NW',
#              '75 Ave NW',
#              '76 Ave NW',
#              '81 Ave',
#              '82 Ave NW',
#              '87 Ave NW',
#              '9 Ave SW',
#              '96 Ave',
#              '96 Ave NW',
#              'Miquelon Ave',
#              'Whyte Ave']),
#  'Ave.': set(['102 Ave. NW',
#               '28 Ave. NW',
#               '51 Ave. NW',
#               'St. & Princess Elisabeth Ave.']),
#  'Avena': set(['Avena Circle', 'Avena Link']),
#  'Avonlea': set(['Avonlea Court', 'Avonlea Way']),
#  'Baie': set(['Baie Madelene', 'Baie Masson']),
#  'Baker': set(['Baker Place']),
#  'Balfour': set(['Balfour Place']),
#  'Balmoral': set(['Balmoral Drive']),
#  'Bamber': set(['Bamber Place']),
#  'Banting': set(['Banting Place']),
#  'Bar': set(['Clover Bar Road']),
#  'Baseline': set(['Baseline Road']),
#  'Bateson': set(['Bateson Street']),
#  'Bathgate': set(['Bathgate Close']),
#  'Bauer': set(['Bauer Avenue']),
#  'Beachview': set(['Beachview Crescent']),
#  'Beacon': set(['Beacon Crescent']),
#  'Beaver': set(['Beaver Crescent']),
#  'Beaverbrook': set(['Beaverbrook Crescent',
#                      'Beaverbrook Drive',
#                      'Beaverbrook Road']),
#  'Becker': set(['Becker Crescent']),
#  'Bedard': set(['Bedard Court']),
#  'Beechmont': set(['Beechmont Avenue', 'Beechmont Crescent']),
#  'Bela': set(['Bela Drive']),
#  'Bell': set(['Bell Bay', 'William Bell Drive']),
#  'Bellaire': set(['Bellaire Street']),
#  'Bellerose': set(['Bellerose Drive']),
#  'Belleville': set(['Belleville Avenue']),
#  'Bellevue': set(['Bellevue Crescent']),
#  'Belmont': set(['Belmont Crescent', 'Belmont Drive']),
#  'Benjamin': set(['Benjamin Road']),
#  'Bennett': set(['Bennett Place']),
#  'Benton': set(['Benton Street']),
#  'Berkeley': set(['Berkeley Street']),
#  'Berland': set(['Berland Crescent']),
#  'Bernard': set(['Bernard Court', 'Bernard Drive']),
#  'Berrymore': set(['Berrymore Drive']),
#  'Bethel': set(['Bethel Drive']),
#  'Beverly': set(['Beverly Avenue']),
#  'Bienert': set(['Bienert Court']),
#  'Birch': set(['Birch Avenue',
#                'Birch Crescent',
#                'Birch Drive',
#                'Birch Place',
#                'Birch Street']),
#  'Birchglen': set(['Birchglen Crescent']),
#  'Birchmont': set(['Birchmont Crescent', 'Birchmont Drive']),
#  'Birchwood': set(['Birchwood Close', 'Birchwood Drive']),
#  'Birkett': set(['Birkett Street']),
#  'Bishop': set(['Bishop Street']),
#  'Blackstone': set(['Blackstone Crescent']),
#  'Blackwell': set(['Blackwell Court']),
#  'Blairmore': set(['Blairmore Place', 'Blairmore Street']),
#  'Blanchard': set(['Rue  Blanchard']),
#  'Blueberry': set(['Blueberry Crescent']),
#  'Blvd': set(['Allard Blvd SW',
#               'East Lapotac Blvd',
#               'Gateway Blvd',
#               'Sunset Blvd Road']),
#  'Blvd.': set(['Gateway Blvd.']),
#  "Bob's": set(["Bob's Way"]),
#  'Bocock': set(['Bocock Place']),
#  'Bohlman': set(['Bohlman Close']),
#  'Bonin': set(['Bonin Crescent', 'Bonin Place']),
#  'Bouchard': set(['Rue  Bouchard', 'Rue Bouchard']),
#  'Boudreau': set(['Boudreau Road']),
#  'Boulder': set(['Boulder Boulevard']),
#  'Boundary': set(['West Boundary Road']),
#  'Bow': set(['Bow Crescent']),
#  'Boxwood': set(['Boxwood Bend']),
#  'Bradburn': set(['Bradburn Crescent']),
#  'Bradbury': set(['William Bradbury Place']),
#  'Brampton': set(['Brampton Street']),
#  'Brantford': set(['Brantford Street']),
#  'Brassard': set(['Brassard Court']),
#  'Brazeau': set(['Brazeau Drive']),
#  'Brebner': set(['Brebner Place']),
#  'Bremner': set(['Bremner Crescent', 'Bremner Drive']),
#  'Brentwood': set(['Brentwood Place']),
#  'Briarwood': set(['Briarwood Point', 'Briarwood Way']),
#  'Bridgeport': set(['Bridgeport Boulevard',
#                     'Bridgeport Court',
#                     'Bridgeport Place',
#                     'Bridgeport Wynd']),
#  'Bridgeview': set(['Bridgeview Close',
#                     'Bridgeview Crescent',
#                     'Bridgeview Drive']),
#  'Brightbank': set(['Brightbank Avenue']),
#  'Bristol': set(['Bristol Way']),
#  'Bristow': set(['Bristow Crescent']),
#  'Brittany': set(['Brittany Crescent']),
#  'Broadmoor': set(['Broadmoor Boulevard']),
#  'Broadview': set(['Broadview Crescent', 'Broadview Drive']),
#  'Broadway': set(['Broadway Boulevard']),
#  'Brochu': set(['Brochu Court']),
#  'Brookhollow': set(['Brookhollow Drive']),
#  'Brookside': set(['Brookside Avenue', 'Brookside Crescent']),
#  'Brookview': set(['Brookview Place', 'Brookview Way']),
#  'Brookwood': set(['Brookwood Crescent',
#                    'Brookwood Drive',
#                    'Brookwood Park',
#                    'Brookwood Place']),
#  'Broomfield': set(['Broomfield Drive']),
#  'Brown': set(['Brown Street', 'J. Brown Place']),
#  'Brunelle': set(['Rue  Brunelle']),
#  'Brunette': set(['Brunette Place']),
#  'Brunswick': set(['Brunswick Crescent']),
#  'Brynmaur': set(['Brynmaur Close']),
#  'Burlington': set(['Burlington Avenue', 'Burlington Place']),
#  'Burnham': set(['Burnham Avenue', 'Burnham Place']),
#  'Burns': set(['Burns Street']),
#  'Burtonsville': set(['Burtonsville Road']),
#  'Butterfield': set(['Butterfield Crescent']),
#  'Cairns': set(['Cairns Close']),
#  'Calahoo': set(['Calahoo Road']),
# ...
#                     '16A Avenue   South-west',
#                     '17 Avenue   South-west',
#                     '17 Street   South-west',
#                     '170 Street   South-west',
#                     '17a Avenue   South-west',
#                     '18 Avenue   South-west',
#                     '181 Street   South-west',
#                     '184 Street   South-west',
#                     '18a Avenue   South-west',
#                     '19 Avenue   South-west',
#                     '1a Avenue   South-west',
#                     '2 Avenue   South-west',
#                     '20 Avenue   South-west',
#                     '205 Street   South-west',
#                     '206 Street   South-west',
#                     '207 Street   South-west',
#                     '21 Avenue   South-west',
#                     '28 Avenue   South-west',
#                     '3 Avenue   South-west',
#                     '30 Avenue   South-west',
#                     '34 Street   South-west',
#                     '4 Avenue   South-west',
#                     '41 Avenue   South-west',
#                     '5 Avenue   South-west',
#                     '50 Street   South-west',
#                     '6 Avenue   South-west',
#                     '62 Street   South-west',
#                     '63 Street   South-west',
#                     '64 Street   South-west',
#                     '65 Street   South-west',
#                     '66 Street   South-west',
#                     '67 Street   South-west',
#                     '68 Street   South-west',
#                     '69 Street   South-west',
#                     '7 Avenue   South-west',
#                     '70 Street   South-west',
#                     '71 Street   South-west',
#                     '72 Street   South-west',
#                     '75 Street   South-west',
#                     '76 Street   South-west',
#                     '77 Street   South-west',
#                     '78 Street   South-west',
#                     '79 Street   South-west',
#                     '7a Avenue   South-west',
#                     '8 Avenue   South-west',
#                     '80 Street   South-west',
#                     '82 Street   South-west',
#                     '83 Street   South-west',
#                     '84 Street   South-west',
#                     '85 Street   South-west',
#                     '86 Street   South-west',
#                     '87 Street   South-west',
#                     '87a Street   South-west',
#                     '88 Street   South-west',
#                     '88a Street   South-west',
#                     '89 Street   South-west',
#                     '89 Street South-west',
#                     '8a Avenue   South-west',
#                     '9 Avenue   South-west',
#                     '90 Street   South-west',
#                     '91 Street   South-west',
#                     'Bailey Court   South-west',
#                     'Baker Close   South-west',
#                     'Ball Cove   South-west',
#                     'Barnes Close   South-west',
#                     'Barnes Link   South-west',
#                     'Barnes Way   South-west',
#                     'Barrie Close   South-west',
#                     'Beck Close   South-west',
#                     'Bell Court   South-west',
#                     'Bishop Point   South-west',
#                     'Blackburn East Drive   South-west',
#                     'Blackburn West Drive   South-west',
#                     'Blackett Wynd   South-west',
#                     'Blacklock Way   South-west',
#                     'Blackmore Court   South-west',
#                     'Blackmore Way   South-west',
#                     'Blackmud Creek Crescent   South-west',
#                     'Blackmud Creek Drive   South-west',
#                     'Blackwood Crescent   South-west',
#                     'Bowen Way   South-west',
#                     'Bowen Wynd   South-west',
#                     'Bowman Point   South-west',
#                     'Bowness Wynd   South-west',
#                     'Byrne Court   South-west',
#                     'Byrne Crescent   South-west',
#                     'Byrne Place   South-west',
#                     'Calgary Trail   South-west',
#                     'Easton Road   South-west',
#                     'Edwards Drive   South-west',
#                     'Ellerslie Road   South-west',
#                     'Ellwood Drive   South-west',
#                     'Gateway Boulevard   South-west',
#                     'Guthrie Point   South-west',
#                     'MacEwan Close   South-west',
#                     'MacEwan Road   South-west',
#                     'MacLean Close   South-west',
#                     'Marion Place   South-west',
#                     'McAllister Court   South-west',
#                     'McAllister Crescent   South-west',
#                     'McAllister Loop   South-west',
#                     'McAllister Way   South-west',
#                     'McKay Lane   South-west',
#                     'McLean Court   South-west',
#                     'McLean Crescent   South-west',
#                     'McMillian Place   South-west',
#                     'McMillian Way   South-west',
#                     'McMullen Green   South-west',
#                     'McMullen Place   South-west',
#                     'McMullen Way   South-west',
#                     'McPhadden Close   South-west',
#                     'McPhadden Place   South-west',
#                     'McPhadden Way   South-west',
#                     'Melrose Place   South-west',
#                     'Parsons Road   South-west',
#                     'Parsons Road South-west',
#                     'Robertson Close   South-west',
#                     'Robertson Crescent   South-west',
#                     'Robertson Place   South-west',
#                     'Robertson Way   South-west',
#                     'Rutherford Close   South-west',
#                     'Rutherford Court   South-west',
#                     'Rutherford Place   South-west',
#                     'Rutherford Point   South-west',
#                     'Rutherford Road   South-west',
#                     'Rutherford Way   South-west',
#                     'Sheppard Court   South-west',
#                     'Sparling Court   South-west',
#                     'Spence Wynd   South-west',
#                     'Stanton Drive   South-west',
#                     'Stewart Crescent   South-west',
#                     'Summerside Cove   South-west',
#                     'Summerside Drive   South-west',
#                     'Summerside Gate   South-west',
#                     'Summerside Link   South-west',
#                     'Winterburn Street   South-west']),
#  'Southfork': set(['Southfork Boulevard',
#                    'Southfork Close',
#                    'Southfork Court',
#                    'Southfork Drive',
#                    'Southfork Green',
#                    'Southfork Place']),
#  'Southfort': set(['Southfort Drive']),
#  'Southridge': set(['Southridge    North-west']),
#  'Southwick': set(['Southwick Boulevard',
#                    'Southwick Point',
#                    'Southwick Street',
#                    'Southwick Way']),
#  'Sparrow': set(['Sparrow Crescent', 'Sparrow Drive']),
#  'Spatinow': set(['Spatinow Drive']),
#  'Spike': set(['Golden Spike Crescent', 'Golden Spike Road']),
#  'Sportsview': set(['Sportsview Drive']),
#  'Springfield': set(['Springfield Crescent']),
#  'Springhill': set(['Springhill Park']),
#  'Spruce': set(['Spruce Avenue',
#                 'Spruce Crescent',
#                 'Spruce Drive',
#                 'Spruce Glen',
#                 'Spruce Road',
#                 'Spruce Street',
#                 'Spruce Way']),
#  'Spruceview': set(['Spruceview Crescent']),
#  'St': set(['102 St NW',
#             '103 A St SW',
#             '106 St NW',
#             '107 St',
#             '111 St NW',
#             '112 St NW',
#             '113 St NW',
#             '115 St NW',
#             '142 St NW',
#             '46A St']),
#  'St.': set(['10140 120 St. NW',
#              '132 St.',
#              '170 St. NW',
#              '66 St. NW',
#              '98 St. NW',
#              'Ave. NW at 66 St.',
#              'Ave. at 83 St.']),
#  'Stanley': set(['Stanley Close', 'Stanley Drive']),
#  'Star-Koy': set(['Star-Koy Place']),
#  'Station': set(['Station Main']),
#  'Sterling': set(['Sterling Street']),
#  'Stoneshire': set(['Stoneshire Close',
#                     'Stoneshire Crescent',
#                     'Stoneshire Manor']),
#  'Sturgeon': set(['North Sturgeon Drive',
#                   'Sturgeon Crescent',
#                   'Sturgeon Drive',
#                   'Sturgeon Road']),
#  'Sunnydale': set(['Sunnydale Road']),
#  'Sunnyside': set(['Sunnyside Crescent']),
#  'Sunrose': set(['Sunrose Lane']),
#  'Sunset': set(['Sunset Boulevard', 'Sunset Drive']),
#  'Suntree': set(['Suntree Promenade']),
#  'Superior': set(['Superior Street']),
#  'Sutherland': set(['Sutherland Street']),
#  'Swallow': set(['Swallow Crescent']),
#  'Sweetberry': set(['Sweetberry Cove']),
#  'Sycamore': set(['Sycamore Avenue']),
#  'Sylvan': set(['Sylvan Drive', 'Sylvan Street']),
#  'Tache': set(['Tache Street']),
#  'Telford': set(['Telford Court']),
#  'Terrault': set(['Terrault Road']),
#  'Third': set(['Third Avenue', 'Third Street']),
#  'Thomas': set(['St. Thomas Street']),
#  'Thompson': set(['Thompson Crescent']),
#  'Umbach': set(['Umbach Road']),
#  'Valhalla': set(['Valhalla Place']),
#  'Valley': set(['Deer Valley Drive',
#                 'Garden Valley Drive',
#                 'Sturgeon Valley Drive',
#                 'Valley Close',
#                 'Valley Court',
#                 'Valley Drive']),
#  'Valleyview': set(['Valleyview Crescent', 'Valleyview Ridge']),
#  'Vaughn': set(['Vaughn Avenue']),
#  'Vega': set(['Vega Avenue', 'Vega Street']),
#  'Venice': set(['Venice Boulevard']),
#  'Ventura': set(['Ventura Street']),
#  'Vernon': set(['Vernon Street']),
#  'Virginia': set(['Virginia Avenue', 'Virginia Loop']),
#  'Viscount': set(['Viscount Crescent',
#                   'Viscount Drive',
#                   'Viscount Place',
#                   'Viscount Road']),
#  'Vital': set(['St. Vital Avenue']),
#  'Wabamun': set(['Wabamun Boulevard']),
#  'Wagner': set(['Wagner Place']),
#  'Wakefield': set(['Wakefield Boulevard', 'Wakefield Place']),
#  'Walden': set(['Walden Crescent', 'Walden Park']),
#  'Walnut': set(['Walnut Place', 'Walnut Street']),
#  'Walters': set(['Walters Court', 'Walters Place', 'Walters Street']),
#  'Wapiti': set(['Wapiti Drive']),
#  'Wascana': set(['Wascana Street']),
#  'Washington': set(['Washington Place']),
#  'Waterford': set(['Waterford Place']),
#  'Waters': set(['Waters Crescent']),
#  'Waverley': set(['Waverley Crescent', 'Waverley Place']),
#  'Waverly': set(['Waverly Drive']),
#  'Weatherby': set(['Weatherby Place']),
#  'Wedgewood': set(['Wedgewood Avenue',
#                    'Wedgewood Crescent',
#                    'Wedgewood Place']),
#  'Welland': set(['Welland Crescent']),
#  'Wellington': set(['Wellington Crescent', 'Wellington Place']),
#  'Wells': set(['Wells Court']),
#  'Wensel': set(['Wensel Avenue']),
#  'Wentworth': set(['Wentworth Crescent']),
#  'Wesleyan': set(['Wesleyan Court']),
#  'West': set(['55 Street West',
#               'Aspen Drive West',
#               'Banff Court West',
#               'Cambrae Drive West',
#               'Campbell Crescent West',
#               'Columbia Avenue West',
#               'Estate Way West',
#               'Harmony Court West',
#               'Jasper Court West',
#               'Millbourne Road West NW',
#               'Saskatchewan Avenue West']),
#  'Westbend': set(['Westbend Street']),
#  'Westbourne': set(['Westbourne Road']),
#  'Westcove': set(['Westcove Place', 'Westcove Street']),
#  'Westerland': set(['Westerland Place']),
#  'Westerra': set(['Westerra Bay',
#                   'Westerra Bend',
#                   'Westerra Boulevard',
#                   'Westerra Close',
#                   'Westerra Court',
#                   'Westerra Crescent',
#                   'Westerra Drive',
#                   'Westerra Key',
#                   'Westerra Link',
#                   'Westerra Place',
#                   'Westerra Point',
#                   'Westerra Terrace',
#                   'Westerra Way']),
#  'Westfield': set(['Westfield Street']),
#  'Westglen': set(['Westglen Crescent']),
#  'Westgrove': set(['Westgrove Drive']),
#  'Westlake': set(['Westlake Drive']),
#  'Westlin': set(['Westlin Court']),
#  'Westmews': set(['Westmews Crescent', 'Westmews Drive']),
#  'Westminster': set(['Westminster Close']),
#  'Weston': set(['Weston Court', 'Weston Drive']),
#  'Westpark': set(['Westpark Boulevard',
#                   'Westpark Court',
#                   'Westpark Drive',
#                   'Westpark Road',
#                   'Westpark Way',
#                   'Westpark Wynd']),
#  'Westridge': set(['Westridge Crescent', 'Westridge Place']),
#  'Westview': set(['Westview Crescent', 'Westview Drive', 'Westview Place']),
#  'Westway': set(['Westway Road']),
#  'Westwood': set(['Westwood Drive',
#                   'Westwood Green',
#                   'Westwood Lane',
#                   'Westwood Place',
#                   'Westwood Point',
#                   'Westwood Way',
#                   'Westwood Wynd']),
#  'Wheatland': set(['Wheatland Avenue']),
#  'Wheatstone': set(['Wheatstone Crescent']),
#  'Whispering': set(['Whispering Cove']),
#  'Whistler': set(['Whistler Place']),
#  'Whitby': set(['Whitby Place']),
#  'Whitehall': set(['Whitehall Crescent']),
#  'Whiteoaks': set(['Whiteoaks Estate']),
#  'Whitman': set(['Whitman Place']),
#  'Whyte': set(['Whyte Ave']),
#  'Wilk': set(['Wilk Drive']),
#  'Wilkinson': set(['Wilkinson Place']),
#  'Willis': set(['Willis Crescent']),
#  'Willoughby': set(['Willoughby Drive']),
#  'Willow': set(['Willow Avenue',
#                 'Willow Crescent',
#                 'Willow Drive',
#                 'Willow Lane',
#                 'Willow Street',
#                 'Willow Way']),
#  'Willowbend': set(['Willowbend Court', 'Willowbend Place']),
#  'Willowbrook': set(['Willowbrook Crescent', 'Willowbrook Pointe']),
#  'Willowby': set(['Willowby Close']),
#  'Willowdale': set(['Willowdale Place']),
#  'Wiloski': set(['Wiloski Street']),
#  'Wilson': set(['Wilson Drive']),
#  'Wimbleton': set(['Wimbleton Crescent']),
#  'Winchester': set(['Winchester Avenue']),
#  'Windermere': set(['Windermere Court',
#                     'Windermere Crescent',
#                     'Windermere Drive']),
#  'Windrose': set(['Windrose Drive']),
#  'Windsor': set(['Windsor Crescent', 'Windsor Place', 'Windsor Street']),
#  'Wingate': set(['Wingate Place']),
#  'Winterburn': set(['Winterburn Rd', 'Winterburn Road']),
#  'Wisteria': set(['Wisteria Lane']),
#  'Wolcott': set(['Wolcott Place']),
#  'Woodbend': set(['Woodbend Way']),
#  'Woodbridge': set(['Woodbridge Link']),
#  'Woodcrest': set(['Woodcrest Avenue']),
#  'Woodhaven': set(['Woodhaven Close', 'Woodhaven Drive']),
#  'Woodhill': set(['Woodhill Lane']),
#  'Woodland': set(['Woodland Greens']),
#  'Woodlands': set(['Woodlands Close', 'Woodlands Road']),
#  'Woodridge': set(['Woodridge Crescent']),
#  'Woodside': set(['Woodside Crescent']),
#  'Woodsmere': set(['Woodsmere Close']),
#  'Woodstock': set(['Woodstock Place']),
#  'Wordsworth': set(['Wordsworth Place']),
#  'Workun': set(['Workun Drive']),
#  'Wycliff': set(['Wycliff Place']),
#  'Wye': set(['21215 Wye Road',
#              '21357 Wye Road',
#              '22322 Wye Road',
#              '22350 Wye Road',
#              '22560 Wye Road',
#              '23033 Wye Road',
#              'Wye Road']),
#  'Yellowhead': set(['Yellowhead Road']),
#  'Yeoman': set(['Yeoman Avenue', 'Yeoman Close']),
#  'Zahar': set(['Zahar Drive']),
#  'Zodiac': set(['Zodiac Drive', 'Zodiac Way']),
#  'a': set(['49th a Street',
#            '51st a Avenue',
#            '52nd a Avenue',
#            '52nd a Street']),
#  'ave': set(['131 ave NW', '48 ave']),
#  'avenue': set(['117 street 87 avenue', '90th avenue']),
#  'calahoo': set(['calahoo Road']),
#  'herert': set(['herert road']),
#  'road': set(['herert road']),
#  'street': set(['101 street',
#                 '107 street',
#                 '109 street',
#                 '127 street',
#                 '170 street'])}

# %% [markdown]
# Apart from numerical highway names and unique street names, there are a surprisingly low amount of inconsistent street types in the dataset.

# %%
mapping = {'Northwest': 'NW', 'Northeast': 'NE', 'Southwest': 'SW', 'Southeast': 'SE', 
           'North-west': 'NW', 'North-east': 'NE', 'South-west': 'SW', 'South-east': 'SE','St':'Street',
           'Ave':'Avenue','Blvd':'Boulevard'}

for event, elem in ET.iterparse(FILEPATH, events=("start",)):# Change to iterate over last 2 elements instead of last one
    if elem.tag == "way":
        for tag in elem.iter("tag"):
            if (is_street_name(tag)):
                print(tag.attrib['v'])
    
#The update mapping function can be contextually created for auditing street names after viewing the incorrect street names 
def update_street(street_name,mapping):
    street_words = street_name.split()
    
    if street_words[len(street_words)-1] != ("North-east" or "North-west" or "South-east"
                                             or "South-west" or "Northeast" or "Northwest" or "Southeast"
                                             or "Southwest"):
        if street_words[len(street_words)-1] in mapping:
            street_words[len(street_words)-1] = mapping[street_words[len(street_words)-1]]
            
    for i in range(len(street_words)):
        if street_words[i] in mapping:
            street_words[i] = mapping[street_words[i]]
    street_name = " ".join(street_words)
    return street_name

for x, ways in street_types.iteritems():
    for name in ways:
        better_name = update_street(name, mapping)
        print name, "=>", better_name
# Out:
# 109 street
# 66 Street NW
# 82 Street NW
# 50 Street NW
# 102A Avenue NW
# 102 Street NW
# 142 Street North-west
# 130 Street NW
# 111 Avenue NW
# Gateway Boulevard NW
# 144 Avenue NW
# 23 Avenue NW
# 107 Street NW
# 107 Street NW
# Wye Road
# Wye Road
# Wye Road
# Wye Road
# 81 Street North-west
# 112 Avenue NW
# 81 Ave
# 109 Street North-west
# 82 Avenue North-west
# Saskatchewan Drive NW
# Whyte Avenue NW
# 84 Avenue NW
# 106 Street NW
# 106 Avenue NW
# 107 Street NW
# Kingsway NW
# 101 Street NW
# 66 Street NW
# Foxtail Link
# Foxtail Link
# Foxtail Link
# Foxtail Link
# Foxtail Link
# Foxtail Link
# Foxtail Link
# Foxtail Link
# Foxtail Link
# Foxtail Link
# 78 Avenue North-west
# 115 Street NW
# 24 Street NW
# 55 Avenue
# 21 Avenue NW
# Bethel Drive
# Bethel Drive
# Emerald Drive
# Emerald Drive
# 38 Avenue NW
# 38 Avenue NW
# 38 Avenue NW
# 38 Avenue NW
# 38 Avenue NW
# 38 Avenue NW
# 38 Avenue NW
# 38 Avenue NW
# 38 Avenue NW
# Meridian Street NW
# 34 Avenue NW
# 24 Street NW
# 24 Street NW
# 24 Street NW
# 23 Avenue NW
# 23 Avenue NW
# 23 Avenue NW
# 28 Avenue NW
# 66 Street NW
# 23 Avenue NW
# 23 Avenue NW
# 23 Avenue NW
# 23 Avenue NW
# 23 Avenue NW
# 23 Avenue NW
# 22 Avenue NW
# 22 Avenue NW
# 23 Avenue NW
# 23 Avenue NW
# Tamarack Green NW
# Fir Street
# 34 Street NW
# 34 Street NW
# 34 Street NW
# 34 Street NW
# 33 Street NW
# 34 Street NW
# 34 Street NW
# 34 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 17 Street NW
# 34 Street NW
# 24 Street NW
# 24 Street NW
# 24 Street NW
# 24 Street NW
# 24 Street NW
# 96 Avenue NW
# Gateway Boulevard SW
# 103A Street NW
# 103A Street NW
# 103A Street NW
# 103A Street NW
# 112 Street NW
# 87 Avenue NW
# 76 Avenue NW
# 1B Avenue SW
# 101 Street NW
# 60A Avenue NW
# 66 Street NW
# 66 Street NW
# 66 Street NW
# 72 Avenue NW
# 23 Avenue NW
# 24 Street NW
# 24 Street NW
# 23 Avenue NW
# 67A Street NW
# Township Road  585A => Township Road 585A
# Kensington Place => Kensington Place
# L' Hirondelle Court => L' Hirondelle Court
# Roche Place => Roche Place
# Township Road  473A => Township Road 473A
# Annette Crescent => Annette Crescent
# 51st Avenue => 51st Avenue
# 51st Street => 51st Street
# Range Road  231A => Range Road 231A
# Oakdale Place => Oakdale Place
# Livingstone Crescent => Livingstone Crescent
# Apache Crescent => Apache Crescent
# Stoneshire Manor => Stoneshire Manor
# Stoneshire Close => Stoneshire Close
# Stoneshire Crescent => Stoneshire Crescent
# Northmount Drive => Northmount Drive
# Range Road  34A => Range Road 34A
# 34A Avenue => 34A Avenue
# Range Road  34B => Range Road 34B
# Henri Close => Henri Close
# Oil Patch Drive => Oil Patch Drive
# Poplar Bay => Poplar Bay
# Poplar Drive => Poplar Drive
# Athapaskan Drive => Athapaskan Drive
# St. Thomas Street => St. Thomas Street
# Windsor Place => Windsor Place
# Windsor Street => Windsor Street
# Windsor Crescent => Windsor Crescent
# Festival Way => Festival Way
# 52004 Range Road 270 => 52004 Range Road 270
# 51420 Range Road 270 => 51420 Range Road 270
# 51214 Range Road 270 => 51214 Range Road 270
# 51222 Range Road 270 => 51222 Range Road 270
# Range Road  270 => Range Road 270
# 51503 Range Road 270 => 51503 Range Road 270
# 51205 Range Road 270 => 51205 Range Road 270
# 51121 Range Road 270 => 51121 Range Road 270
# Range Road 270 => Range Road 270
# 51113 Range Road 270 => 51113 Range Road 270
# 52020 Range Road 270 => 52020 Range Road 270
# 52215 Range Road 270 => 52215 Range Road 270
# 51425 Range Road 271 => 51425 Range Road 271
# 51410 Range Road 271 => 51410 Range Road 271
# Range Road  271 => Range Road 271
# 53219 Range Road 271 => 53219 Range Road 271
# 51121 Range Road 271 => 51121 Range Road 271
# 51426 Range Road 271 => 51426 Range Road 271
# 51330 Range Road 271 => 51330 Range Road 271
# Range Road 271 => Range Road 271
# 51409 Range Road 271 => 51409 Range Road 271
# 51524 Range Road 271 => 51524 Range Road 271
# 52524 Range Road 271 => 52524 Range Road 271
# 53521 Range Road 272 => 53521 Range Road 272
# 53522 Range Road 272 => 53522 Range Road 272
# 51032 Range Road 272 => 51032 Range Road 272
# Range Road  272 => Range Road 272
# 51421 Range Road 272 => 51421 Range Road 272
# Range Road 272 => Range Road 272
# 52212 Range Road 272 => 52212 Range Road 272
# 53412 Range Road 272 => 53412 Range Road 272
# 101 street => 101 street
# 109 street => 109 street
# 127 street => 127 street
# 170 street => 170 street
# 107 street => 107 street
# 54006 Range Road 274 => 54006 Range Road 274
# 53424 Range Road 274 => 53424 Range Road 274
# 53522 Range Road 274 => 53522 Range Road 274
# 52112 Range Road 274 => 52112 Range Road 274
# 52120 Range Road 274 => 52120 Range Road 274
# Range Road  274 => Range Road 274
# 53420 Range Road 274 => 53420 Range Road 274
# 52212 Range Road 274 => 52212 Range Road 274
# 52132 Range Road 274 => 52132 Range Road 274
# 53504 Range Road 274 => 53504 Range Road 274
# 54030 Range Road 274 => 54030 Range Road 274
# 53503 Range Road 274 => 53503 Range Road 274
# 52222 Range Road 274 => 52222 Range Road 274
# 52312 Range Road 274 => 52312 Range Road 274
# 54129 Range Road 275 => 54129 Range Road 275
# 54022 Range Road 275 => 54022 Range Road 275
# 54014 Range Road 275 => 54014 Range Road 275
# 50410 Range Road 275 => 50410 Range Road 275
# 53206 Range Road 275 => 53206 Range Road 275
# Range Road  275 => Range Road 275
# 50412 Range Road 275 => 50412 Range Road 275
# 53203 Range Road 275 => 53203 Range Road 275
# 54106 Range Road 275 => 54106 Range Road 275
# 52218 Range Road 275 => 52218 Range Road 275
# 53532 Range Road 275 => 53532 Range Road 275
# 52211 Range Road 275 => 52211 Range Road 275
# 52125 Range Road 275 => 52125 Range Road 275
# 52001 Range Road 275 => 52001 Range Road 275
# 54030 Range Road 275 => 54030 Range Road 275
# 54029 Range Road 275 => 54029 Range Road 275
# 52224 Range Road 275 => 52224 Range Road 275
# 53310 Range Road 275 => 53310 Range Road 275
# 52208 Range Road 275 => 52208 Range Road 275
# Grassview Crescent => Grassview Crescent
# Grassview Close => Grassview Close
# Brightbank Avenue => Brightbank Avenue
# Eastcott Drive => Eastcott Drive
# Range Road  244C => Range Road 244C
# Range Road  244A => Range Road 244A
# Hamilton Crescent => Hamilton Crescent
# Primeau Lane => Primeau Lane
# Danfield Court => Danfield Court
# 28 Ave. NW => 28 Ave. NW
# 102 Ave. NW => 102 Ave. NW
# St. & Princess Elisabeth Ave. => St. & Princess Elisabeth Ave.
# 51 Ave. NW => 51 Ave. NW
# Sioux Road => Sioux Road
# Woodland Greens => Woodland Greens
# Clover Drive => Clover Drive
# 108 Avenue => 108 Avenue
# 108 Street => 108 Street
# 109 Avenue => 109 Avenue
# 109 street => 109 street
# 109 Street => 109 Street
# 102 Avenue => 102 Avenue
# 102 Street => 102 Street
# 103 Street => 103 Street
# 103 Avenue => 103 Avenue
# 100 Avenue => 100 Avenue
# 100 Street => 100 Street
# Sturgeon 100 Crescent => Sturgeon 100 Crescent
# 101 Avenue => 101 Avenue
# 101 street => 101 street
# 101 Street => 101 Street
# 106 Avenue => 106 Avenue
# 106 Street => 106 Street
# 107 Street => 107 Street
# 107 street => 107 street
# 107 Avenue => 107 Avenue
# 107 St => 107 Street
# 104 Street => 104 Street
# 104 Avenue => 104 Avenue
# 105 Street => 105 Street
# 105 Avenue => 105 Avenue
# Merrill Street => Merrill Street
# Mohr Avenue => Mohr Avenue
# Queen Street => Queen Street
# Rue  Blanchard => Rue Blanchard
# St. & Princess Elisabeth Ave. => St. & Princess Elisabeth Ave.
# Keillor Drive => Keillor Drive
# Shep Street => Shep Street
# Spruce Avenue => Spruce Avenue
# Spruce Glen => Spruce Glen
# Spruce Way => Spruce Way
# Spruce Street => Spruce Street
# Spruce Crescent => Spruce Crescent
# Spruce Drive => Spruce Drive
# Spruce Road => Spruce Road
# Orleans Court => Orleans Court
# Ave. at 83 St. => Ave. at 83 St.
# 66 St. NW => 66 St. NW
# 98 St. NW => 98 St. NW
# 170 St. NW => 170 St. NW
# 10140 120 St. NW => 10140 120 St. NW
# Ave. NW at 66 St. => Ave. NW at 66 St.
# 132 St. => 132 St.
# Southridge    North-west => Southridge NW
# Kelso Court => Kelso Court
# Bamber Place => Bamber Place
# Northwood Crescent => Northwood Crescent
# Vernon Street => Vernon Street
# Gentry Court => Gentry Court
# Gentry Lane => Gentry Lane
# Arndt Court => Arndt Court
# 99 Avenue => 99 Avenue
# 99 Street => 99 Street
# 98 Street => 98 Street
# 98 Avenue => 98 Avenue
# Emerson Place => Emerson Place
# Gould Place => Gould Place
# 91 Avenue => 91 Avenue
# 91 Street => 91 Street
# 90 Street => 90 Street
# 90 Avenue => 90 Avenue
# 93 Avenue => 93 Avenue
# 93 Street => 93 Street
# 92 Avenue => 92 Avenue
# 92 Street => 92 Street
# 95 Avenue => 95 Avenue
# 95 Street => 95 Street
# 94 Street => 94 Street
# 94 Avenue => 94 Avenue
# 97 Street => 97 Street
# 97 Avenue => 97 Avenue
# Waverley Crescent => Waverley Crescent
# Waverley Place => Waverley Place
# Ho-Hum Crescent => Ho-Hum Crescent
# Hilldowns Drive => Hilldowns Drive
# Orion Close => Orion Close
# Whispering Cove => Whispering Cove
# Westgrove Drive => Westgrove Drive
# St. Clair Street => St. Clair Street
# Jespersen Avenue => Jespersen Avenue
# Adamic Crescent => Adamic Crescent
# Kingsford Crescent => Kingsford Crescent
# Willowdale Place => Willowdale Place
# Township Road  554 => Township Road 554
# 26500 Township Road 554 => 26500 Township Road 554
# Township Road  551 => Township Road 551
# Township Road  550 => Township Road 550
# Township Road  553 => Township Road 553
# 24400 Township Road 552 => 24400 Township Road 552
# Township Road  552 => Township Road 552
# Balfour Place => Balfour Place
# Leveque Way => Leveque Way
# Eagle Point => Eagle Point
# Township Road  553A => Township Road 553A
# Lakewood Drive => Lakewood Drive
# Lakewood Close => Lakewood Close
# Lakewood Crescent => Lakewood Crescent
# Lakewood Boulevard => Lakewood Boulevard
# Montrose Boulevard => Montrose Boulevard
# Leger Road => Leger Road
# Winterburn Road => Winterburn Road
# Winterburn Rd => Winterburn Rd
# Falcon Crescent => Falcon Crescent
# Greenview Crescent => Greenview Crescent
# Laurent Place => Laurent Place
# Craigen Court => Craigen Court
# Marlin Street => Marlin Street
# Wilk Drive => Wilk Drive
# Township Road  545A => Township Road 545A
# Montcalm Crescent => Montcalm Crescent
# 55a Avenue => 55a Avenue
# Huntington Drive => Huntington Drive
# Huntington Bay => Huntington Bay
# Huntington Crescent => Huntington Crescent
# Erie Street => Erie Street
# Avena Circle => Avena Circle
# Avena Link => Avena Link
# 41st Avenue => 41st Avenue
# 1407 Township Road 514 => 1407 Township Road 514
# 27004 Township Road 514 => 27004 Township Road 514
# 22334 Township Road 514 => 22334 Township Road 514
# 27019 Township Road 514 => 27019 Township Road 514
# 23109 Township Road 514 => 23109 Township Road 514
# 23045 Township Road 514 => 23045 Township Road 514
# 26516 Township Road 514 => 26516 Township Road 514
# 26312 Township Road 514 => 26312 Township Road 514
# 26328 Township Road 514 => 26328 Township Road 514
# 26320 Township Road 514 => 26320 Township Road 514
# 26515 Township Road 514 => 26515 Township Road 514
# 23114 Township Road 514 => 23114 Township Road 514
# 27222 Township Road 514 => 27222 Township Road 514
# 26222 Township Road 514 => 26222 Township Road 514
# Township Road  514 => Township Road 514
# 22450 Township Road 514 => 22450 Township Road 514
# 26510 Township Road 514 => 26510 Township Road 514
# Lloyd Place => Lloyd Place
# 55A Street => 55A Street
# Kenilworth Crescent => Kenilworth Crescent
# Ebony Way => Ebony Way
# 55B Street => 55B Street
# Gold Eye Drive => Gold Eye Drive
# 37A Avenue => 37A Avenue
# Edith Crescent => Edith Crescent
# Blackstone Crescent => Blackstone Crescent
# Dalquist Bay => Dalquist Bay
# Addison Crescent => Addison Crescent
# Abbott Crescent => Abbott Crescent
# Hardcastle Place => Hardcastle Place
# Gatewood Avenue => Gatewood Avenue
# Lakevista Point => Lakevista Point
# Helen Place => Helen Place
# Duhaime Place => Duhaime Place
# Burns Street => Burns Street
# 629 Highway => 629 Highway
# Onesti Place => Onesti Place
# Wordsworth Place => Wordsworth Place
# Hickory Trail => Hickory Trail
# Ashwood Street => Ashwood Street
# Brookhollow Drive => Brookhollow Drive
# Birchwood Drive => Birchwood Drive
# Birchwood Close => Birchwood Close
# Rue  Marseille => Rue Marseille
# Rowland Crescent => Rowland Crescent
# Township Road  562B => Township Road 562B
# Township Road 562A => Township Road 562A
# Township Road  562A => Township Road 562A
# Goebel Close => Goebel Close
# Goebel Drive => Goebel Drive
# Goebel Place => Goebel Place
# Goebel Bay => Goebel Bay
# Hartwick Loop => Hartwick Loop
# Hartwick Landing => Hartwick Landing
# Hartwick Mews => Hartwick Mews
# Hartwick Way => Hartwick Way
# Hartwick Gate => Hartwick Gate
# Walden Park => Walden Park
# Walden Crescent => Walden Crescent
# Haviland Crescent => Haviland Crescent
# Gretna Place => Gretna Place
# Duncan Court => Duncan Court
# 57th Avenue => 57th Avenue
# Sunnyside Crescent => Sunnyside Crescent
# Derek Drive => Derek Drive
# Deerbourne Drive => Deerbourne Drive
# Parkwood Drive => Parkwood Drive
# Terrault Road => Terrault Road
# Discovery Way => Discovery Way
# Discovery Avenue => Discovery Avenue
# Township Road  462A => Township Road 462A
# Aspen Way => Aspen Way
# Aspen Gate => Aspen Gate
# Aspen Place => Aspen Place
# Aspen Crescent => Aspen Crescent
# Aspen Wynd => Aspen Wynd
# Aspen Avenue => Aspen Avenue
# Aubrey Place => Aubrey Place
# Highway 60 & Miquelon Avenue => Highway 60 & Miquelon Avenue
# Miquelon Avenue => Miquelon Avenue
# Miquelon Ave => Miquelon Avenue
# Napoleon Crescent => Napoleon Crescent
# Galloway Wynd => Galloway Wynd
# 54324 Range Road 245 => 54324 Range Road 245
# Range Road  245 => Range Road 245
# Range Road 245 => Range Road 245
# Range Road  244 => Range Road 244
# Range Road 244 => Range Road 244
# Range Road  241 => Range Road 241
# Range Road 241 => Range Road 241
# Range Road  240 => Range Road 240
# Range Road 240 => Range Road 240
# Range Road 243 => Range Road 243
# Range Road  243 => Range Road 243
# Range Road 242 => Range Road 242
# Range Road  242 => Range Road 242
# Range Road  230A => Range Road 230A
# Township Road  472A => Township Road 472A
# Carleton Drive => Carleton Drive
# Wensel Avenue => Wensel Avenue
# Lucien Drive => Lucien Drive
# Orangewood Place => Orangewood Place
# Embassy Place => Embassy Place
# Grayridge Crescent => Grayridge Crescent
# Grayridge Bay => Grayridge Bay
# Waterford Place => Waterford Place
# 170 street => 170 street
# Mehden Road => Mehden Road
# Dumont Court => Dumont Court
# 40th Avenue => 40th Avenue
# Alexander Drive => Alexander Drive
# Scarboro Place => Scarboro Place
# Ashgrove Bay => Ashgrove Bay
# Creekside Point => Creekside Point
# Creekside Close => Creekside Close
# Creekside Way => Creekside Way
# Creekside Drive => Creekside Drive
# Sunset Boulevard => Sunset Boulevard
# Sunset Drive => Sunset Drive
# Selkirk Place => Selkirk Place
# Township Road  482B => Township Road 482B
# Township Road  482C => Township Road 482C
# Township Road  482A => Township Road 482A
# Stony Plain Rd. => Stony Plain Rd.
# Ave. at Groat Rd. NW => Ave. at Groat Rd. NW
# Matthew Road => Matthew Road
# Carroll Court => Carroll Court
# Kurylik Boulevard => Kurylik Boulevard
# Hillside Way => Hillside Way
# Hillside Terrace => Hillside Terrace
# Hillside Place => Hillside Place
# Hillside Drive => Hillside Drive
# Hillside Court => Hillside Court
# 52225 Range Road 273 => 52225 Range Road 273
# Range Road  273 => Range Road 273
# 53306 Range Road 273 => 53306 Range Road 273
# 53305 Range Road 273 => 53305 Range Road 273
# 51526 Range Road 273 => 51526 Range Road 273
# Range Road 273 => Range Road 273
# Madonna Drive => Madonna Drive
# 17 Street   North-east => 17 Street North-east
# 259 Avenue   North-east => 259 Avenue North-east
# Meridian Street   North-east => Meridian Street North-east
# 211 Avenue   North-east => 211 Avenue North-east
# 244 Avenue   North-east => 244 Avenue North-east
# 33 Street   North-east => 33 Street North-east
# 25 Street   North-east => 25 Street North-east
# 195 Avenue   North-east => 195 Avenue North-east
# 3 Street   North-east => 3 Street North-east
# Fort Road   North-east => Fort Road North-east
# 9 Street   North-east => 9 Street North-east
# 167 Avenue   North-east => 167 Avenue North-east
# 197 Avenue   North-east => 197 Avenue North-east
# Service Road   North-east => Service Road North-east
# Range Road  245A => Range Road 245A
# Range Road  245C => Range Road 245C
# Range Road  245B => Range Road 245B
# Rhonda Bay => Rhonda Bay
# Copperhead Place => Copperhead Place
# Graywood Cove => Graywood Cove
# Township Road  505A => Township Road 505A
# Township Road  544C => Township Road 544C
# Holly Place => Holly Place
# Township Road  544A => Township Road 544A
# Yeoman Avenue => Yeoman Avenue
# Yeoman Close => Yeoman Close
# Township Road  544D => Township Road 544D
# Linwood Crescent => Linwood Crescent
# Donlevy Place => Donlevy Place
# St. Albert Road => St. Albert Road
# St. Albert Trail => St. Albert Trail
# St Albert Trail => Street Albert Trail
# St Albert Road => Street Albert Road
# Devon Close => Devon Close
# Ash Point => Ash Point
# Mountain Ash Drive => Mountain Ash Drive
# Green Ash Drive => Green Ash Drive
# Ash Place => Ash Place
# Ash Street => Ash Street
# Ash Crescent => Ash Crescent
# Ash Close => Ash Close
# 49th Avenue => 49th Avenue
# 49th Street => 49th Street
# 45th Street => 45th Street
# 45th Avenue => 45th Avenue
# Flamingo Drive => Flamingo Drive
# Weatherby Place => Weatherby Place
# Benton Street => Benton Street
# Olivier Close => Olivier Close
# Ivan Road => Ivan Road
# Hilltop Ridge => Hilltop Ridge
# Zodiac Drive => Zodiac Drive
# Zodiac Way => Zodiac Way
# Rue Monette => Rue Monette
# Lakeside Drive => Lakeside Drive
# Lakeside Crescent => Lakeside Crescent
# Lakeside Point => Lakeside Point
# Grandin Lakeside Village => Grandin Lakeside Village
# Lakeside Close => Lakeside Close
# Lakeside Place => Lakeside Place
# Lakeside Green => Lakeside Green
# Fieldstone Drive => Fieldstone Drive
# Fieldstone Place => Fieldstone Place
# Fieldstone Crescent => Fieldstone Crescent
# Fieldstone Gate => Fieldstone Gate
# Fieldstone Cove => Fieldstone Cove
# Fieldstone Close => Fieldstone Close
# Kingston Close => Kingston Close
# Garfield Place => Garfield Place
# Hillcrest Place => Hillcrest Place
# Hillcrest Court => Hillcrest Court
# Hillcrest Point => Hillcrest Point
# Hillcrest Drive => Hillcrest Drive
# Laval Drive => Laval Drive
# Township Road  483A => Township Road 483A
# Range Road  41A => Range Road 41A
# 41A Street => 41A Street
# 41A Avenue => 41A Avenue
# 41B Street => 41B Street
# 41B Avenue => 41B Avenue
# Pointe Marcelle => Pointe Marcelle
# Ordze Avenue => Ordze Avenue
# Ordze Road => Ordze Road
# St. Anne Street => St. Anne Street
# Lac St Anne Trail => Lac Street Anne Trail
# Dalhousie Street => Dalhousie Street
# Private Roadway    North-west => Private Roadway NW
# Equestrian Place => Equestrian Place
# Star-Koy Place => Star-Koy Place
# Township Road  543 => Township Road 543
# 23061 Township Road 543 => 23061 Township Road 543
# 1103 Township Road 540 => 1103 Township Road 540
# 1418 Township Road 540 => 1418 Township Road 540
# 21252 Township Road 540 => 21252 Township Road 540
# 27528 Township Road 540 => 27528 Township Road 540
# 27420 Township Road 540 => 27420 Township Road 540
# Township Road  540 => Township Road 540
# 1307 Township Road 540 => 1307 Township Road 540
# 1325 Township Road 540 => 1325 Township Road 540
# 1017 Township Road 540 => 1017 Township Road 540
# 28018 Township Road 540 => 28018 Township Road 540
# Township Road  541 => Township Road 541
# 21255 Township Road 544 => 21255 Township Road 544
# Township Road  544 => Township Road 544
# Township Road  545 => Township Road 545
# Grandin Village => Grandin Village
# Grandin Place => Grandin Place
# Grandin Drive => Grandin Drive
# Grandin Road => Grandin Road
# calahoo Road => calahoo Road
# Pembroke Crescent => Pembroke Crescent
# 54A Avenue => 54A Avenue
# 54A Street => 54A Street
# Wakefield Place => Wakefield Place
# Wakefield Boulevard => Wakefield Boulevard
# Gloucester Drive => Gloucester Drive
# Parkview Bay => Parkview Bay
# Parkview Crescent => Parkview Crescent
# Parkview Drive => Parkview Drive
# Armstrong Crescent => Armstrong Crescent
# Washington Place => Washington Place
# Township Road  550A => Township Road 550A
# Dunewood Place => Dunewood Place
# Anderson Court => Anderson Court
# Township Road  475A => Township Road 475A
# McPherson Avenue => McPherson Avenue
# St. John Street => St. John Street
# Sportsview Drive => Sportsview Drive
# 48th Avenue => 48th Avenue
# 48th Street => 48th Street
# Cobblestone Court => Cobblestone Court
# Fermont Street => Fermont Street
# Huxley Cove => Huxley Cove
# Pinnacle Place => Pinnacle Place
# Pinnacle Way => Pinnacle Way
# Pinnacle Key => Pinnacle Key
# Gennieve Point => Gennieve Point
# 44th Street => 44th Street
# 44th Avenue => 44th Avenue
# Derrick Drive => Derrick Drive
# Lindbergh Crescent => Lindbergh Crescent
# Lasalle Point => Lasalle Point
# Wiloski Street => Wiloski Street
# Aberdeen Crescent => Aberdeen Crescent
# Aberdeen Place => Aberdeen Place
# Aberdeen Way => Aberdeen Way
# Edgemont Point => Edgemont Point
# Huot Place => Huot Place
# Petroleum Way => Petroleum Way
# Range Road  251B => Range Road 251B
# Range Road  251C => Range Road 251C
# Lorraine Crescent => Lorraine Crescent
# Dunfield Crescent => Dunfield Crescent
# Lafonde Crescent => Lafonde Crescent
# Range Road 252 => Range Road 252
# Range Road  252 => Range Road 252
# Range Road 253 => Range Road 253
# Range Road  253 => Range Road 253
# Range Road 250 => Range Road 250
# Range Road  250 => Range Road 250
# Range Road 251 => Range Road 251
# Range Road  251 => Range Road 251
# Range Road  254 => Range Road 254
# Range Road 254 => Range Road 254
# Range Road  255 => Range Road 255
# Range Road 255 => Range Road 255
# Oakcrest Terrace => Oakcrest Terrace
# Kastle Pointe => Kastle Pointe
# Marlboro Drive => Marlboro Drive
# Marlboro Place => Marlboro Place
# Waters Crescent => Waters Crescent
# 16A Highway => 16A Highway
# Westerose Acreage Road => Westerose Acreage Road
# Hillary Place => Hillary Place
# Dunvegan Court => Dunvegan Court
# Range Road  242A => Range Road 242A
# Range Road  242B => Range Road 242B
# Range Road 242B => Range Road 242B
# Mohawk Crescent => Mohawk Crescent
# Georgia Place => Georgia Place
# Norelle Terrace => Norelle Terrace
# Glenhall Crescent => Glenhall Crescent
# Range Road  220A => Range Road 220A
# Coronado Drive => Coronado Drive
# Township Road  465A => Township Road 465A
# 13 St & 167 Ave => 13 St & 167 Avenue
# 160 Avenue => 160 Avenue
# Township Road  463B => Township Road 463B
# Range Road  25A => Range Road 25A
# Campbell Road => Campbell Road
# Campbell Drive => Campbell Drive
# Campbell Court => Campbell Court
# Wingate Place => Wingate Place
# Ellis Court => Ellis Court
# Main Avenue => Main Avenue
# Main Street => Main Street
# Station Main => Station Main
# Main Boulevard => Main Boulevard
# Greenbriar Place => Greenbriar Place
# Bellerose Drive => Bellerose Drive
# Fairview Boulevard => Fairview Boulevard
# Glenmanor Crescent => Glenmanor Crescent
# Bristow Crescent => Bristow Crescent
# Champlain Place => Champlain Place
# Morris Street => Morris Street
# Morris Road => Morris Road
# Bristol Way => Bristol Way
# Gresham Boulevard => Gresham Boulevard
# Coal Mine Road => Coal Mine Road
# Hanratty Point => Hanratty Point
# Range Road  273A => Range Road 273A
# Exploration Drive => Exploration Drive
# Portland Place => Portland Place
# 53A Street => 53A Street
# 1510 Parkland Drive => 1510 Parkland Drive
# 2022 Parkland Drive => 2022 Parkland Drive
# 2519 Parkland Drive => 2519 Parkland Drive
# 2208 Parkland Drive => 2208 Parkland Drive
# Parkland Drive => Parkland Drive
# 1511 Parkland Drive => 1511 Parkland Drive
# 2228 Parkland Drive => 2228 Parkland Drive
# Lavoie Place => Lavoie Place
# Golden Spike Road => Golden Spike Road
# Golden Spike Crescent => Golden Spike Crescent
# 53a Street => 53a Street
# 53a Avenue => 53a Avenue
# Township Road  551A => Township Road 551A
# Loyola Place => Loyola Place
# Leonard Drive => Leonard Drive
# Foxboro Run => Foxboro Run
# Groat Drive => Groat Drive
# Groat Place => Groat Place
# Groat Crescent => Groat Crescent
# Lazerte Place => Lazerte Place
# Obrien Drive => Obrien Drive
# James Street => James Street
# James Drive => James Drive
# Ember Court => Ember Court
# Barnes Way   South-west => Barnes Way SW
# Calgary Trail   South-west => Calgary Trail SW
# 118a Street   South-west => 118a Street SW
# Stanton Drive   South-west => Stanton Drive SW
# Sheppard Court   South-west => Sheppard Court SW
# 17 Avenue   South-west => 17 Avenue SW
# 84 Street   South-west => 84 Street SW
# 79 Street   South-west => 79 Street SW
# 14a Avenue   South-west => 14a Avenue SW
# Blackett Wynd   South-west => Blackett Wynd SW
# McAllister Crescent   South-west => McAllister Crescent SW
# 82 Street   South-west => 82 Street SW
# MacEwan Close   South-west => MacEwan Close SW
# 63 Street   South-west => 63 Street SW
# Easton Road   South-west => Easton Road SW
# 90 Street   South-west => 90 Street SW
# 85 Street   South-west => 85 Street SW
# 76 Street   South-west => 76 Street SW
# 205 Street   South-west => 205 Street SW
# Ball Cove   South-west => Ball Cove SW
# Summerside Drive   South-west => Summerside Drive SW
# 28 Avenue   South-west => 28 Avenue SW
# 4 Avenue   South-west => 4 Avenue SW
# Byrne Court   South-west => Byrne Court SW
# 11 Avenue   South-west => 11 Avenue SW
# 16 Avenue   South-west => 16 Avenue SW
# McMillian Way   South-west => McMillian Way SW
# 19 Avenue   South-west => 19 Avenue SW
# 124 Avenue   South-west => 124 Avenue SW
# 41 Avenue   South-west => 41 Avenue SW
# Rutherford Court   South-west => Rutherford Court SW
# 181 Street   South-west => 181 Street SW
# Robertson Close   South-west => Robertson Close SW
# 91 Street   South-west => 91 Street SW
# 88a Street   South-west => 88a Street SW
# Bishop Point   South-west => Bishop Point SW
# 88 Street   South-west => 88 Street SW
# MacEwan Road   South-west => MacEwan Road SW
# 72 Street   South-west => 72 Street SW
# Parsons Road South-west => Parsons Road SW
# Ellerslie Road   South-west => Ellerslie Road SW
# 15 Avenue   South-west => 15 Avenue SW
# MacLean Close   South-west => MacLean Close SW
# 1a Avenue   South-west => 1a Avenue SW
# 8a Avenue   South-west => 8a Avenue SW
# Beck Close   South-west => Beck Close SW
# McPhadden Place   South-west => McPhadden Place SW
# Barrie Close   South-west => Barrie Close SW
# 75 Street   South-west => 75 Street SW
# Robertson Place   South-west => Robertson Place SW
# 71 Street   South-west => 71 Street SW
# Bowness Wynd   South-west => Bowness Wynd SW
# Blackmore Court   South-west => Blackmore Court SW
# Rutherford Road   South-west => Rutherford Road SW
# McMullen Green   South-west => McMullen Green SW
# 9 Avenue   South-west => 9 Avenue SW
# Robertson Crescent   South-west => Robertson Crescent SW
# 15a Avenue   South-west => 15a Avenue SW
# 18a Avenue   South-west => 18a Avenue SW
# 13 Avenue   South-west => 13 Avenue SW
# 65 Street   South-west => 65 Street SW
# 101 Street   South-west => 101 Street SW
# Edwards Drive   South-west => Edwards Drive SW
# 113 Street   South-west => 113 Street SW
# McPhadden Way   South-west => McPhadden Way SW
# 34 Street   South-west => 34 Street SW
# 68 Street   South-west => 68 Street SW
# 111 Street   South-west => 111 Street SW
# 77 Street   South-west => 77 Street SW
# Rutherford Close   South-west => Rutherford Close SW
# 20 Avenue   South-west => 20 Avenue SW
# Rutherford Point   South-west => Rutherford Point SW
# 2 Avenue   South-west => 2 Avenue SW
# 30 Avenue   South-west => 30 Avenue SW
# Blackwood Crescent   South-west => Blackwood Crescent SW
# Melrose Place   South-west => Melrose Place SW
# Byrne Crescent   South-west => Byrne Crescent SW
# 18 Avenue   South-west => 18 Avenue SW
# 112 Street   South-west => 112 Street SW
# 156 Street   South-west => 156 Street SW
# Blackburn East Drive   South-west => Blackburn East Drive SW
# 80 Street   South-west => 80 Street SW
# Bowen Wynd   South-west => Bowen Wynd SW
# Bell Court   South-west => Bell Court SW
# 170 Street   South-west => 170 Street SW
# McMillian Place   South-west => McMillian Place SW
# 122 Street   South-west => 122 Street SW
# Barnes Link   South-west => Barnes Link SW
# 107 Street   South-west => 107 Street SW
# Guthrie Point   South-west => Guthrie Point SW
# 114 Street   South-west => 114 Street SW
# Summerside Cove   South-west => Summerside Cove SW
# McPhadden Close   South-west => McPhadden Close SW
# 115 Street   South-west => 115 Street SW
# McKay Lane   South-west => McKay Lane SW
# McLean Court   South-west => McLean Court SW
# 123 Street   South-west => 123 Street SW
# 5 Avenue   South-west => 5 Avenue SW
# 127 Street   South-west => 127 Street SW
# McLean Crescent   South-west => McLean Crescent SW
# Barnes Close   South-west => Barnes Close SW
# Bowen Way   South-west => Bowen Way SW
# 125 Street   South-west => 125 Street SW
# 21 Avenue   South-west => 21 Avenue SW
# Summerside Gate   South-west => Summerside Gate SW
# McAllister Way   South-west => McAllister Way SW
# 67 Street   South-west => 67 Street SW
# Blackmore Way   South-west => Blackmore Way SW
# 6 Avenue   South-west => 6 Avenue SW
# 12 Avenue   South-west => 12 Avenue SW
# 86 Street   South-west => 86 Street SW
# 118 Street   South-west => 118 Street SW
# 121 Street   South-west => 121 Street SW
# 7a Avenue   South-west => 7a Avenue SW
# Robertson Way   South-west => Robertson Way SW
# 120 Street   South-west => 120 Street SW
# Blackmud Creek Crescent   South-west => Blackmud Creek Crescent SW
# 119a Street   South-west => 119a Street SW
# 87a Street   South-west => 87a Street SW
# 16A Avenue   South-west => 16A Avenue SW
# 62 Street   South-west => 62 Street SW
# 66 Street   South-west => 66 Street SW
# 7 Avenue   South-west => 7 Avenue SW
# Rutherford Way   South-west => Rutherford Way SW
# 3 Avenue   South-west => 3 Avenue SW
# Baker Close   South-west => Baker Close SW
# 64 Street   South-west => 64 Street SW
# 70 Street   South-west => 70 Street SW
# 119 Street   South-west => 119 Street SW
# 87 Street   South-west => 87 Street SW
# McMullen Place   South-west => McMullen Place SW
# Gateway Boulevard   South-west => Gateway Boulevard SW
# 108 Street   South-west => 108 Street SW
# 206 Street   South-west => 206 Street SW
# 69 Street   South-west => 69 Street SW
# Rutherford Place   South-west => Rutherford Place SW
# 17a Avenue   South-west => 17a Avenue SW
# Bowman Point   South-west => Bowman Point SW
# 89 Street South-west => 89 Street SW
# Winterburn Street   South-west => Winterburn Street SW
# Blackmud Creek Drive   South-west => Blackmud Creek Drive SW
# 83 Street   South-west => 83 Street SW
# Byrne Place   South-west => Byrne Place SW
# McMullen Way   South-west => McMullen Way SW
# 50 Street   South-west => 50 Street SW
# 141 Street   South-west => 141 Street SW
# 120a Street   South-west => 120a Street SW
# 117 Street   South-west => 117 Street SW
# 89 Street   South-west => 89 Street SW
# 207 Street   South-west => 207 Street SW
# Stewart Crescent   South-west => Stewart Crescent SW
# Ellwood Drive   South-west => Ellwood Drive SW
# 17 Street   South-west => 17 Street SW
# Blackburn West Drive   South-west => Blackburn West Drive SW
# McAllister Loop   South-west => McAllister Loop SW
# 184 Street   South-west => 184 Street SW
# McAllister Court   South-west => McAllister Court SW
# 116 Street   South-west => 116 Street SW
# 107a Street   South-west => 107a Street SW
# Spence Wynd   South-west => Spence Wynd SW
# 8 Avenue   South-west => 8 Avenue SW
# Sparling Court   South-west => Sparling Court SW
# 14 Avenue   South-west => 14 Avenue SW
# 10 Avenue   South-west => 10 Avenue SW
# 126 Street   South-west => 126 Street SW
# 147 Avenue   North-west => 147 Avenue NW
# Hollick-Kenyon Road   North-west => Hollick-Kenyon Road NW
# Hewes Way   North-west => Hewes Way NW
# 61b Street   North-west => 61b Street NW
# Hodgson Court   North-west => Hodgson Court NW
# Kaasa West Road   North-west => Kaasa West Road NW
# Hooke Road   North-west => Hooke Road NW
# Clareview Road   North-west => Clareview Road NW
# Elsinore Close   North-west => Elsinore Close NW
# Caldwell Court   North-west => Caldwell Court NW
# Rowland Road   North-west => Rowland Road NW
# 169 Avenue   North-west => 169 Avenue NW
# West Port Close   North-west => West Port Close NW
# 140a Avenue   North-west => 140a Avenue NW
# 99a Avenue   North-west => 99a Avenue NW
# Patricia Crescent   North-west => Patricia Crescent NW
# 106b Avenue North-west => 106b Avenue NW
# Graydon Court   North-west => Graydon Court NW
# 171a Avenue   North-west => 171a Avenue NW
# Wolf Ridge Way   North-west => Wolf Ridge Way NW
# Ower Place   North-west => Ower Place NW
# Eleniak Road   North-west => Eleniak Road NW
# 161 Avenue   North-west => 161 Avenue NW
# 90a Avenue   North-west => 90a Avenue NW
# MacKenzie Drive   North-west => MacKenzie Drive NW
# Wolf Ridge Close   North-west => Wolf Ridge Close NW
# Lemieux Close   North-west => Lemieux Close NW
# 166a Street   North-west => 166a Street NW
# Martell Place   North-west => Martell Place NW
# West Strait Place   North-west => West Strait Place NW
# 75a Street   North-west => 75a Street NW
# Meadow Crescent   North-west => Meadow Crescent NW
# Wahstao Road   North-west => Wahstao Road NW
# 53a Avenue   North-west => 53a Avenue NW
# Dechene Way   North-west => Dechene Way NW
# 135a Avenue   North-west => 135a Avenue NW
# Wolf Willow Point   North-west => Wolf Willow Point NW
# 135a Street   North-west => 135a Street NW
# Picard Drive   North-west => Picard Drive NW
# 179a Avenue   North-west => 179a Avenue NW
# Buchanan Road   North-west => Buchanan Road NW
# Hodgson Close   North-west => Hodgson Close NW
# Hanna Crescent   North-west => Hanna Crescent NW
# 148 Street   North-west => 148 Street NW
# 110 Avenue   North-west => 110 Avenue NW
# Youville West Drive   North-west => Youville West Drive NW
# 91 Street   North-west => 91 Street NW
# Kulawy Gate   North-west => Kulawy Gate NW
# 61 Street   North-west => 61 Street NW
# 99a Street   North-west => 99a Street NW
# Latta Place   North-west => Latta Place NW
# 90a Street   North-west => 90a Street NW
# Haswell Place   North-west => Haswell Place NW
# 101 Street   North-west => 101 Street NW
# Cairns Bay   North-west => Cairns Bay NW
# Winterburn Road   North-west => Winterburn Road NW
# Twin Brooks Way   North-west => Twin Brooks Way NW
# Larose Drive => Larose Drive
# Keystone Crescent => Keystone Crescent
# Keystone Way => Keystone Way
# Keystone Lane => Keystone Lane
# Dundas Place => Dundas Place
# 56a Avenue => 56a Avenue
# Township Road  542A => Township Road 542A
# Fleetwood Crescent => Fleetwood Crescent
# Lauralcrest Place => Lauralcrest Place
# Dunlop Wynd => Dunlop Wynd
# Lawrence Crescent => Lawrence Crescent
# St. Lawrence Avenue => St. Lawrence Avenue
# 22169 Township Road 530 => 22169 Township Road 530
# 22459 Township Road 530 => 22459 Township Road 530
# 22343 Township Road 530 => 22343 Township Road 530
# 22051 Township Road 530 => 22051 Township Road 530
# 21252 Township Road 530 => 21252 Township Road 530
# 22151 Township Road 530 => 22151 Township Road 530
# Township Road  530 => Township Road 530
# 2311 Township Road 530 => 2311 Township Road 530
# 22555 Township Road 530 => 22555 Township Road 530
# Escallier Place => Escallier Place
# Morinville Drive => Morinville Drive
# Range Road  281A => Range Road 281A
# 56A Street => 56A Street
# 4A Street => 4A Street
# Escada Close => Escada Close
# Parkridge Crescent => Parkridge Crescent
# Haida Avenue => Haida Avenue
# Township Road  560 => Township Road 560
# Township Road 560 => Township Road 560
# Township Road  561 => Township Road 561
# Township Road 562 => Township Road 562
# Township Road  562 => Township Road 562
# Township Road  563 => Township Road 563
# Township Road  564 => Township Road 564
# Township Road  565 => Township Road 565
# Highland Way => Highland Way
# Highland Crescent => Highland Crescent
# Highland Drive => Highland Drive
# Oakpark Crescent => Oakpark Crescent
# Hesse Place => Hesse Place
# 27324 Township Road 533A => 27324 Township Road 533A
# Athabasca Avenue => Athabasca Avenue
# Athabasca Acres => Athabasca Acres
# Athabasca Drive => Athabasca Drive
# Industrial Avenue => Industrial Avenue
# Black Gold Drive => Black Gold Drive
# Camelot Crescent => Camelot Crescent
# Camelot Avenue => Camelot Avenue
# Camelot Place => Camelot Place
# Kingsbury Crescent => Kingsbury Crescent
# 47A Avenue => 47A Avenue
# 47A Street => 47A Street
# 90th avenue => 90th avenue
# Donahue Close => Donahue Close
# Township Road  563A => Township Road 563A
# Township Road 563A => Township Road 563A
# Pinegrove Place => Pinegrove Place
# Northridge Road => Northridge Road
# 48 Street => 48 Street
# 48 ave => 48 ave
# 48 Avenue => 48 Avenue
# 49 Street => 49 Street
# 49 Avenue => 49 Avenue
# 46 Avenue => 46 Avenue
# 46 Street => 46 Street
# 47 Street => 47 Street
# 47 Avenue => 47 Avenue
# 44 Highway => 44 Highway
# 44 Street => 44 Street
# 44 Avenue => 44 Avenue
# 53304 Highway 44 => 53304 Highway 44
# 45 Avenue => 45 Avenue
# 45 Street => 45 Street
# 42 Avenue => 42 Avenue
# 42 Street => 42 Street
# Range Road  42 => Range Road 42
# 43 Street => 43 Street
# 43 Avenue => 43 Avenue
# 43 Highway => 43 Highway
# Wells Court => Wells Court
# 41 Avenue => 41 Avenue
# 41 Street => 41 Street
# 53426 Range Road 41 => 53426 Range Road 41
# Range Road  41 => Range Road 41
# 53412 Range Road 41 => 53412 Range Road 41
# Enderby Crescent => Enderby Crescent
# Rayborn Crescent => Rayborn Crescent
# Milburn Crescent => Milburn Crescent
# Wentworth Crescent => Wentworth Crescent
# 140 ST Mathews Ave => 140 ST Mathews Avenue
# St. Mathews Avenue => St. Mathews Avenue
# Page Drive => Page Drive
# Erie Street South => Erie Street South
# Calgary Trail South => Calgary Trail South
# 1 Avenue South => 1 Avenue South
# 2 Avenue South => 2 Avenue South
# Lakewood Road South NW => Lakewood Road South NW
# 1 Street South => 1 Street South
# Golden Spike Road South => Golden Spike Road South
# Railway Avenue South => Railway Avenue South
# South Avenue => South Avenue
# Knottwood Road South NW => Knottwood Road South NW
# 2 Street South => 2 Street South
# Oakridge Drive South => Oakridge Drive South
# 1st Avenue South => 1st Avenue South
# Linden Street South => Linden Street South
# 3rd Avenue South => 3rd Avenue South
# 2nd Avenue South => 2nd Avenue South
# Lac St Anne Trail South => Lac St Anne Trail South
# Huron Street South => Huron Street South
# Lakewood Cove South => Lakewood Cove South
# Glenview South => Glenview South
# Jasper Court South => Jasper Court South
# Dover Road => Dover Road
# Dover Court => Dover Court
# Prospect Place => Prospect Place
# Township Road  552A => Township Road 552A
# Township Road  552B => Township Road 552B
# Sparrow Drive => Sparrow Drive
# Sparrow Crescent => Sparrow Crescent
# Township Road  472 => Township Road 472
# Township Road  473 => Township Road 473
# Township Road  470 => Township Road 470
# Township Road  471 => Township Road 471
# Township Road  474 => Township Road 474
# Township Road  475 => Township Road 475

# %% [markdown]
# Zipcodes in Edmonton must have the following format:
#
# 1)The first 3 letters must be T5A
# 2)The next character must be 0,1, or 2
# 3)The next character must be an alphabet
# 4)The next character must be a number between 1-9
# 5)Overall the zipcode's length must be 6
#
# We can check if there are any zipcodes that violate these rules and audit them accordingly.

# %%
"""Zipcodes in Edmonton must have the following format:
The first 3 letters must be T5A and the length of the zipcode must be 6.
We can check if there are any zipcodes that violate these rules and audit them accordingly.
Due to the low number of incorrect zipcodes, I choose to remove the incorrect zipcodes"""


wrong_codes = []

    
for event, elem in ET.iterparse(FILEPATH, events=("start",)):# Change to iterate over last 2 elements instead of last one
    if elem.tag == "way":
        for tag in elem.iter("tag"):
            if (is_zipcode(tag)):
                tag.attrib['v'] = tag.attrib['v'].replace(" ", "")
                audit_zipcode(tag.attrib['v'],wrong_codes)
                if tag in wrong_codes:
                    tag.attrib['v'] = None

# %% [markdown]
# ## 5. Converting our data to prepare for insertion into an SQL database

# %%
#Conversion to SQL schema taken from "Preparing for Database - SQL" from the Case Study:Open street map Module



OSM_PATH = FILEPATH

NODES_PATH = "nodes.csv"
NODE_TAGS_PATH = "nodes_tags.csv"
WAYS_PATH = "ways.csv"
WAY_NODES_PATH = "ways_nodes.csv"
WAY_TAGS_PATH = "ways_tags.csv"

LOWER_COLON = re.compile(r'^([a-z]|_)+:([a-z]|_)+')
PROBLEMCHARS = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


# Make sure the fields order in the csvs matches the column order in the sql table schema
NODE_FIELDS = ['id', 'lat', 'lon', 'user', 'uid', 'version', 'changeset', 'timestamp']
NODE_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_FIELDS = ['id', 'user', 'uid', 'version', 'changeset', 'timestamp']
WAY_TAGS_FIELDS = ['id', 'key', 'value', 'type']
WAY_NODES_FIELDS = ['id', 'node_id', 'position']


def shape_element(element, node_attr_fields=NODE_FIELDS, way_attr_fields=WAY_FIELDS,
                  problem_chars=PROBLEMCHARS, default_tag_type='regular'):
    """Clean and shape node or way XML element to Python dict"""

    node_attribs = {}
    way_attribs = {}
    way_nodes = []
    tags = []  # Handle secondary tags the same way for both node and way elements

    if element.tag == 'node':
        for item in NODE_FIELDS:
            if element.attrib[item] is not None:
                node_attribs[item] = element.attrib[item] #Gets the value for the key
        for child in element.iter("tag"): #all children who's name is tag
            if problem_chars.match(child.attrib['k']): #ignore the tag
                continue
            tag_to_insert = {} #node tagged
            tag_to_insert['id'] = node_attribs['id']     
            key_check = child.attrib['k']
            if child.attrib['k'] == "addr:street":
                child.attrib['v'] = update_street(child.attrib['v'],mapping)
            if child.attrib['k'] == "addr:postcode":
                filler = []
                child.attrib['v'] = child.attrib['v'].replace(" ", "")
                child.attrib['v'] = audit_zipcode(child.attrib['v'],filler)
            if ':' in key_check:
                ind = child.attrib['k'].index(":")
                tag_to_insert['key'] = child.attrib['k'][ind+1:]
                tag_to_insert['value'] = child.attrib['v']
                tag_to_insert['type'] = child.attrib['k'][:ind]
            else:
                tag_to_insert['key'] = child.attrib['k']
                tag_to_insert['type'] = "regular"
            tags.append(tag_to_insert)
        return {'node': node_attribs, 'node_tags': tags}
    
    elif element.tag == 'way':
        for item in WAY_FIELDS:
            if element.attrib[item] is not None:
                way_attribs[item] = element.attrib[item]
        
        for child in element.iter("tag"):
            if problem_chars.match(child.attrib['k']): #ignore the tag
                continue
            else:
                tag_to_insert = {} #node tagged
                tag_to_insert['id'] = way_attribs['id']     
                key_check = child.attrib['k']
                if child.attrib['k'] == "addr:street":
                    child.attrib['v'] = update_street(child.attrib['v'],mapping)
                if child.attrib['k'] == "addr:postcode":
                    filler = []
                    child.attrib['v'] = child.attrib['v'].replace(" ", "")
                    child.attrib['v'] = audit_zipcode(child.attrib['v'],filler)
                if ':' in key_check:
                    ind = child.attrib['k'].index(":")
                    tag_to_insert['key'] = child.attrib['k'][ind+1:]
                    tag_to_insert['value'] = child.attrib['v']
                    tag_to_insert['type'] = child.attrib['k'][:ind]
                else:
                    tag_to_insert['key'] = child.attrib['k']
                    tag_to_insert['type'] = "regular"
                tags.append(tag_to_insert)
        c = 0
        for child in element.iter():
            if child.tag == "nd":
                nd ={}
                nd['id'] = way_attribs['id']
                nd['node_id'] = child.attrib['ref']
                nd['position'] = c
                c+=1
                way_nodes.append(nd)
        return {'way': way_attribs, 'way_nodes': way_nodes, 'way_tags': tags}



# ================================================== #
#               Helper Functions                     #
# ================================================== #
SCHEMA = schema.schema
def get_element(osm_file, tags=('node', 'way', 'relation')):
    """Yield element if it is the right type of tag"""

    context = ET.iterparse(osm_file, events=('start', 'end'))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()


def validate_element(element, validator, schema=SCHEMA):
    """Raise ValidationError if element does not match schema"""
    if validator.validate(element, schema) is not True:
        field, errors = next(validator.errors.iteritems())
        message_string = "\nElement of type '{0}' has the following errors:\n{1}"
        error_strings = (
            "{0}: {1}".format(k, v if isinstance(v, str) else ", ".join(v))
            for k, v in errors.iteritems()
        )
        raise cerberus.ValidationError(
            message_string.format(field, "\n".join(error_strings))
        )



class UnicodeDictWriter(csv.DictWriter, object):
    """Extend csv.DictWriter to handle Unicode input"""

    def writerow(self, row):
        super(UnicodeDictWriter, self).writerow({
            k: (v.encode('utf-8') if isinstance(v, unicode) else v) for k, v in row.iteritems()
        })

    def writerows(self, rows):
        for row in rows:
            self.writerow(row)


# ================================================== #
#               Main Function                        #
# ================================================== #
def process_map(file_in, validate):
    """Iteratively process each XML element and write to csv(s)"""

    with codecs.open(NODES_PATH, 'w') as nodes_file, \
         codecs.open(NODE_TAGS_PATH, 'w') as nodes_tags_file, \
         codecs.open(WAYS_PATH, 'w') as ways_file, \
         codecs.open(WAY_NODES_PATH, 'w') as way_nodes_file, \
         codecs.open(WAY_TAGS_PATH, 'w') as way_tags_file:

        nodes_writer = UnicodeDictWriter(nodes_file, NODE_FIELDS)
        node_tags_writer = UnicodeDictWriter(nodes_tags_file, NODE_TAGS_FIELDS)
        ways_writer = UnicodeDictWriter(ways_file, WAY_FIELDS)
        way_nodes_writer = UnicodeDictWriter(way_nodes_file, WAY_NODES_FIELDS)
        way_tags_writer = UnicodeDictWriter(way_tags_file, WAY_TAGS_FIELDS)

        nodes_writer.writeheader()
        node_tags_writer.writeheader()
        ways_writer.writeheader()
        way_nodes_writer.writeheader()
        way_tags_writer.writeheader()

        validator = cerberus.Validator()

        for element in get_element(file_in, tags=('node', 'way')):
            el = shape_element(element)
            if el:
                if validate is True:
                    validate_element(el, validator)

                if element.tag == 'node':
                    nodes_writer.writerow(el['node'])
                    node_tags_writer.writerows(el['node_tags'])
                elif element.tag == 'way':
                    ways_writer.writerow(el['way'])
                    way_nodes_writer.writerows(el['way_nodes'])
                    way_tags_writer.writerows(el['way_tags'])



#I am only using process_map to validate the data in the sample_testing file since it is too slow for a larger dataset
process_map(OSM_PATH, validate=False)

# %% [markdown]
# ## 6. Further insights through querying

# %% [markdown]
# I will now create a database using sqlite3 and the csv files and query the database to obtain more insights. First, we can check the number of user who contributed to the code. It should be around 619.

# %% [markdown]
# ### FILE SIZES
#
# edmonton_canada.osm => 784 MB
#
# nodes.csv => 312 MB
# nodes_tags.csv => 18.95 MB
#
# ways.csv => 28.05 MB
#
# ways_tags.csv => 102.4 MB
#
# ways_nodes.csv => 25.6 MB
#
# p3main.db(the sql database) => 581 MB

# %%
import sqlite3

#Setting up cursor and querying the number of unique users
conn = sqlite3.connect('p3final.db')
conn.text_factory = str
c = conn.cursor()

query = ("SELECT count(DISTINCT user) FROM (SELECT user FROM ways UNION ALL SELECT user FROM nodes);")
c.execute(query)
print(c.fetchall()[0][0])
# Out:
# 614

# %%
#The dataset is massive. The number of entries in each table are: 

query = ("SELECT count(*) FROM nodes");
c.execute(query)
print("nodes: "+ str(c.fetchall()[0][0]))
query = ("SELECT count(*) FROM ways");
c.execute(query)
print("ways: "+ str(c.fetchall()[0][0]))
query = ("SELECT count(*) FROM nodes_tags")
c.execute(query)
print("nodes_tags: " + str(c.fetchall()[0][0]))
query = ("SELECT count(*) FROM ways_tags")
c.execute(query)
print("ways_tags: "+ str(c.fetchall()[0][0]))
query = ("SELECT count(*) FROM ways_nodws")
c.execute(query)
print("ways_nodes: "+ str(c.fetchall()[0][0]))
# Out:
# nodes: 3698501
# ways: 465338
# nodes_tags: 557266
# ways_tags: 871375
# ways_nodes: 4202209

# %%
#Now querying to find the user with the most submissions

query = ("SELECT user,count(user) FROM nodes GROUP BY user UNION SELECT user,count(user) FROM ways GROUP BY user ORDER BY count(user) DESC;")
c.execute(query)
print(c.fetchall()[0])
# Out:
# ('edmontongeo', 2119823)

# %% [markdown]
# It is not surprising that edmontongeo remains the user with the highest submissions

# %%
query =("SELECT distinct value,count(value) FROM nodes_tags WHERE key LIKE '%city' GROUP BY value UNION SELECT distinct value,count(value) FROM ways_tags WHERE key LIKE '%city' GROUP BY value ORDER BY count(value) DESC;")
c.execute(query)
print c.fetchall()
# Out:
# [('Edmonton', 75598), ('Parkland County', 5552), ('Strathcona County', 5289), ('Sturgeon County', 4910), ('St. Albert', 4540), ('Leduc County', 3876), ('Westlock County', 2558), ('Leduc', 2465), ('Spruce Grove', 2066), ('Fort Saskatchewan', 1903), ('Lac Ste. Anne County', 1595), ('Wetaskiwin', 1425), ('Stony Plain', 1422), ('Thorhild No. 7, County of', 1403), ('Wetaskiwin No. 10, County of', 1281), ('Beaumont', 1264), ('Barrhead No. 11, County of', 1126), ('Morinville', 911), ('Edmonton', 845), ('Barrhead', 711), ('Westlock', 632), ('Devon', 597), ('Redwater', 400), ('Gibbons', 334), ('Camrose County', 333), ('Millet', 292), ('Sherwood Park', 281), ('Alberta Beach', 266), ('Thorsby', 248), ('Calmar', 247), ('Nisku', 239), ('Legal', 230), ('Bon Accord', 222), ('Thorhild', 214), ('Warburg', 206), ('Onoway', 192), ('Cardiff', 152), ('Wabamun', 148), ('Breton', 126), ('Clyde', 126), ('Hay Lakes', 82), ('Brazeau County', 77), ('Spring Lake', 76), ('Val Quentin', 72), ('New Sarepta', 64), ('Sherwood Park', 55), ('Spruce Grove', 53), ('Ma-Me-O Beach', 50), ('Ardrossan', 48), ('Sunset Point', 46), ('Norris Beach', 44), ('Mulhurst Bay', 38), ('Bittern Lake', 36), ('South Cooking Lake', 36), ('Duffield', 34), ('Ross Haven', 34), ('Pickardville', 32), ('West Cove', 32), ('Hastings Lake', 28), ('Pine Sands', 24), ('Alcomdale', 22), ('Josephburg', 22), ('Keephills', 22), ('Saint Albert', 22), ('Nakamun Park', 19), ('Sundance Beach', 16), ('Westerose', 16), ('Birch Cove', 15), ('Yellowstone', 14), ('Buford', 12), ('Calahoo', 12), ('Collingwood Cove', 12), ('Half Moon Lake', 12), ('Poplar Bay', 12), ('Egremont', 10), ('', 9), ('St. Albert', 9), ('Alexander #134', 8), ('Carbondale', 8), ('Gwynne', 8), ('Rich Valley', 8), ('Mearns', 6), ('Riviere Qui Barre', 6), ('Villeneuve', 6), ('Camrose', 5), ('Lakeview', 4), ('Pigeon Lake #138A', 4), ('Winfield', 4), ('', 3), ('Camrose', 3), ('Fort Saskatchewan', 3), ('edmonton', 3), ('Edmonton ', 2), ('Yellowstone', 2), ('Acheson', 1), ('Acheson ', 1), ('Beaumont', 1), ('Devon', 1), ('Edmonron', 1), ('Edmonton ', 1), ('Edmonton International Airport', 1), ('Edmonton, AB', 1), ('Leduc', 1), ('Morinville', 1), ('Smokey Lake', 1), ('Smoky Lake', 1), ('St Albert', 1), ('Tofield', 1), ('edmonton', 1)]

# %% [markdown]
# The data appears very inconsistent with multiple "Edmonton" city values. This is one of the major problems with user submitted data. In addition to this, we can conclude that the map area used is not only that for edmonton but for surrounding towns and counties as well.

# %%
query = ("SELECT key,count(*) FROM nodes_tags GROUP BY key ORDER BY count(*) DESC")
c.execute(query)
print(c.fetchall())
# Out:
# [('source', 130584), ('housenumber', 126644), ('street', 126642), ('city', 126521), ('highway', 12398), ('power', 10497), ('name', 9490), ('amenity', 2120), ('fixme', 1135), ('natural', 781), ('railway', 777), ('barrier', 677), ('created_by', 648), ('shop', 549), ('place', 528), ('type', 503), ('website', 448), ('cuisine', 342), ('en', 322), ('operator', 320), ('building', 319), ('postcode', 242), ('species', 221), ('man_made', 203), ('phone', 200), ('network', 184), ('ref', 177), ('leisure', 170), ('tourism', 168), ('wikipedia', 148), ('crossing', 136), ('traffic_signals', 136), ('province', 110), ('wikidata', 105), ('note', 98), ('population', 92), ('entrance', 88), ('opening_hours', 61), ('sport', 61), ('religion', 58), ('traffic_calming', 58), ('country', 53), ('description', 51), ('covered', 50), ('is_in', 50), ('bicycle_parking', 49), ('waterway', 49), ('aeroway', 46), ('foot', 45), ('adm1', 44), ('cc1', 44), ('comment', 44), ('dms_lat', 44), ('dms_long', 44), ('dsg', 44), ('fc', 44), ('jog', 44), ('lat', 44), ('long', 44), ('mgrs', 44), ('n:xx:full_name', 44), ('n:xx:full_name_nd', 44), ('n:xx:modify_date', 44), ('n:xx:nt', 44), ('n:xx:sort_name', 44), ('rc', 44), ('ufi', 44), ('uni', 44), ('email', 43), ('bicycle', 41), ('wheelchair', 39), ('landuse', 37), ('FIXME', 31), ('denomination', 29), ('internet_access', 29), ('smoking', 26), ('emergency', 24), ('url', 24), ('level', 23), ('drive_through', 22), ('material', 22), ('housename', 20), ('parking', 20), ('access', 19), ('historic', 19), ('fut_name', 18), ('motor_vehicle', 18), ('construction', 17), ('proposed', 17), ('shelter_type', 17), ('bitcoin', 16), ('fax', 16), ('atm', 15), ('state', 15), ('store_name', 15), ('information', 14), ('office', 14), ('brand', 13), ('pipeline', 13), ('alt_name', 12), ('addr', 11), ('alberta_school_number', 11), ('horse', 11), ('takeaway', 11), ('old_name', 10), ('backrest', 9), ('seasonal', 9), ('colour', 6), ('continent', 6), ('levels', 6), ('motorcar', 6), ('recycling_type', 6), ('seats', 6), ('shelter', 6), ('collection_times', 5), ('ele', 5), ('fee', 5), ('fut_ref', 5), ('noexit', 5), ('public_transport', 5), ('sloped_curb', 5), ('surface', 5), ('wifi', 5), ('bollard', 4), ('cans', 4), ('club', 4), ('delivery', 4), ('dispensing', 4), ('disposal', 4), ('fr', 4), ('platforms', 4), ('ru', 4), ('shop_1', 4), ('alt_name_1', 3), ('artwork_type', 3), ('capacity', 3), ('crossing_ref', 3), ('designation', 3), ('diesel', 3), ('fireplace', 3), ('glass', 3), ('iata', 3), ('icao', 3), ('ko', 3), ('playground', 3), ('tactile_paving', 3), ('train', 3), ('vending', 3), ('yelp', 3), ('artist_name', 2), ('board_type', 2), ('button_operated', 2), ('cartons', 2), ('coins', 2), ('de', 2), ('destination', 2), ('drive_in', 2), ('es', 2), ('height', 2), ('hi', 2), ('hiking', 2), ('junction', 2), ('layer', 2), ('motorcycle', 2), ('octane_100', 2), ('outdoor_seating', 2), ('paper', 2), ('postal_code', 2), ('ski', 2), ('sport_1', 2), ('stop', 2), ('traffic_sign', 2), ('uk', 2), ('zh', 2), ('zh_pinyin', 2), ('3D', 1), ('HGV_diesel', 1), ('Street', 1), ('alt_name_2', 1), ('amenity_1', 1), ('american_express', 1), ('ar', 1), ('batteries', 1), ('bench', 1), ('beverage_cartons', 1), ('bicycle:pump', 1), ('capital', 1), ('cardboard', 1), ('cash', 1), ('category', 1), ('clothes', 1), ('construction_date', 1), ('converstruction', 1), ('country_code', 1), ('craft', 1), ('created_on', 1), ('credit_cards', 1), ('debit_cards', 1), ('disused', 1), ('electrical_appliances', 1), ('enforcement', 1), ('facebook', 1), ('flashing_lights', 1), ('for', 1), ('genus', 1), ('glass_bottles', 1), ('gr', 1), ('heritage', 1), ('hoops', 1), ('hour_on', 1), ('indoor', 1), ('industrial', 1), ('int_name', 1), ('ja', 1), ('leaf_type', 1), ('linkedin', 1), ('lit', 1), ('local_ref', 1), ('magazines', 1), ('mastercard', 1), ('microbrewery', 1), ('mn', 1), ('newspaper', 1), ('notes', 1), ('octane_91', 1), ('octane_95', 1), ('octane_98', 1), ('official_name', 1), ('organic', 1), ('paper_packag ...

# %% [markdown]
# This query reveals a major problem. Most of these values for the corresponding keys are empty.

# %% [markdown]
# A lot of random querying such as (SELECT * FROM nodes_tags WHERE key= 'amenity') produced null results in the values column. This suggests further cleaning is required to obtain reasonable insights. Almost all nodes_tags have a key but no value. This shows a lack of full utilization of the OSM featureset or the existence of problematic characters. A major reason may be that Edmonton is not an extremely dense or populus city like New York or San Francisco thus has a lower userbase constantly updating data. Some suggestions for improvement include a unified data entry scheme on the OSM website, where unnecesscary tags are not created if the user does not fill in the value. This can work in a format similar to google docs, where the user fill out their pertinent contribution in a form(name of the place, type of place, address, zipcode, etc) and the data is inserted through a backend process which can also act as a auto-correcter to prevent the user from entering nonsensical data.
#
# As it stands, there remains no initiative to have a unified format for the data. This can be fixed by automating a lot of self-correction and user entry processes to make the data that does pass through cleaner than raw user submitted data.

# %% [markdown]
# ## Sources

# %% [markdown]
# http://gimme-shelter.com/term-2/steet-types-designations-abbreviations-50006/
#
# https://www.crummy.com/software/BeautifulSoup/bs3/documentation.html#The%20basic%20find%20method:%20findAll(name,%20attrs,%20recursive,%20text,%20limit,%20**kwargs)
#
# http://stackoverflow.com/questions/13482586/how-can-i-tell-python-to-take-the-last-2-words-from-an-email-that-is-in-a-list-l
#
# http://stackoverflow.com/questions/26871866/print-highest-value-in-dict-with-key
#
# https://gist.github.com/carlward/54ec1c91b62a5f911c42#file-sample_project-md
#
# All relevent coursework in Udacity Data Analyst Nanodegree(especially the Case:Study OSM and XML module)
